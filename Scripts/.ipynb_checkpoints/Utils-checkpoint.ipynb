# %% [markdown]
# ##### This code will create a file with all the linear regression output
# ### The output files can then be use to create a qqplot based on genomewide data vs by chr
# ### Just change the Tissue path to obtain the results

# %%
import matplotlib.pyplot as plt
import pandas as pd

Frames=[pd.read_csv('/storage/szfeupe/Runs/GTEx_estr/Analysis_by_Tissue/Artery-Tibial/chr1/Lin_Reg_Out',sep='\t')]
for x in range(2,23):
    LN='/storage/szfeupe/Runs/GTEx_estr/Analysis_by_Tissue/Artery-Tibial/chr'+str(x)+'/Lin_Reg_Out'
    frame1=pd.read_csv(LN, sep='\t')
    Frames.append(frame1)
    print('Chr',x,'    ',frame1.shape)
Results=pd.concat(Frames)
print('\n All Chrms ','   ', Results.shape)
Results.to_csv('/storage/szfeupe/Runs/GTEx_estr/Analysis_by_Tissue/Artery-Tibial/Lin_Reg_Out', sep='\t', header=True)

print('Continuing...')

Frames=[pd.read_csv('/storage/szfeupe/Runs/GTEx_estr/Analysis_by_Tissue/Artery-Tibial/chr1/Lin_Reg_Out_perm',sep='\t')]
for x in range(2,23):
    LN='/storage/szfeupe/Runs/GTEx_estr/Analysis_by_Tissue/Artery-Tibial/chr'+str(x)+'/Lin_Reg_Out_perm'
    frame1=pd.read_csv(LN, sep='\t')
    Frames.append(frame1)
    print('Chr',x,'    ',frame1.shape)
Results=pd.concat(Frames)
print('\n All Chrms ','   ', Results.shape)
Results.to_csv('/storage/szfeupe/Runs/GTEx_estr/Analysis_by_Tissue/Artery-Tibial/Lin_Reg_Out_perm', sep='\t', header=True)
print('THE END')
# Out:
# Chr 2      (102452, 12)
# Chr 3      (89168, 12)
# Chr 4      (55512, 12)
# Chr 5      (69445, 12)
# Chr 6      (43631, 12)
# Chr 7      (78987, 12)
# Chr 8      (50478, 12)
# Chr 9      (17249, 12)
# Chr 10      (64442, 12)
# Chr 11      (81918, 12)
# Chr 12      (90605, 12)
# Chr 13      (25721, 12)
# Chr 14      (51365, 12)
# Chr 15      (53247, 12)
# Chr 16      (42955, 12)
# Chr 17      (103106, 12)
# Chr 18      (22844, 12)
# Chr 19      (65233, 12)
# Chr 20      (40914, 12)
# Chr 21      (14282, 12)
# Chr 22      (40408, 12)
#
#  All Chrms      (1294301, 12)
# Continuing...
# Chr 2      (102452, 12)
# Chr 3      (89168, 12)
# Chr 4      (55512, 12)
# Chr 5      (69445, 12)
# Chr 6      (43631, 12)
# Chr 7      (78987, 12)
# Chr 8      (50478, 12)
# Chr 9      (17249, 12)
# Chr 10      (64442, 12)
# Chr 11      (81918, 12)
# Chr 12      (90605, 12)
# Chr 13      (25721, 12)
# Chr 14      (51365, 12)
# Chr 15      (53247, 12)
# Chr 16      (42955, 12)
# Chr 17      (103106, 12)
# ...

# %% [markdown]
# ### This code is targeted at comparing the intercept from previous and current analysis
# ### I will start with only chr1

# %%
import matplotlib.pyplot as plt
import pandas as pd

#Get IDs
#Get peerfactors #V1 V2 V3 V4 ... V17
oldestr = pd.read_csv('/storage/szfeupe/Runs/GTEx_estr/2016_estrs_table.csv',sep=',')
chr1str = oldestr.loc[oldestr['chrom'].isin(['chr1'])]
#chr1str = chr1str.sort(columns='str.start', ascending=True)
#print(chr1str)
newestr = pd.read_csv('/storage/szfeupe/Runs/GTEx_estr/Analysis_by_Tissue/WholeBlood/chr1/Lin_Reg_Out',sep='\t')
#newestr = newestr.sort(columns='str.start', ascending=True)
#print(newestr)
G1 = chr1str.loc[chr1str['gene'].isin(['ENSG00000188976'])]
#G2 = [x.split('.')[0] for x in list(chr1str['str.start'])]
G2 = newestr.loc[newestr['gene'].isin(['ENSG00000188976.6'])]
#inters=[s for s in Genes1 if s in Genes2]
#print(len([s for s in Genes1 if s in Genes2]))
G2
# Out:
#                  gene chrom      str.id  str.start  n.miss allele1.dummy  \
# 51  ENSG00000188976.6  chr1  STR_793323     793323       5             A
# 52  ENSG00000188976.6  chr1  STR_795982     795982       2             A
# 53  ENSG00000188976.6  chr1  STR_804593     804593      16             A
# 54  ENSG00000188976.6  chr1  STR_804978     804978       4             A
# 55  ENSG00000188976.6  chr1  STR_807303     807303      20             A
# 56  ENSG00000188976.6  chr1  STR_834405     834405      23             A
# 57  ENSG00000188976.6  chr1  STR_838154     838154       6             A
# 58  ENSG00000188976.6  chr1  STR_842617     842617       8             A
# 59  ENSG00000188976.6  chr1  STR_842917     842917      17             A
# 60  ENSG00000188976.6  chr1  STR_850323     850323       9             A
# 61  ENSG00000188976.6  chr1  STR_866512     866512      18             A
# 62  ENSG00000188976.6  chr1  STR_872771     872771      58             A
# ...

# %%
G1
# Out:
#                   gene chrom  str.start      beta   beta.se  linreg.pval  \
# 14099  ENSG00000188976  chr1     954851 -0.015697  0.093647     0.867176
# 14100  ENSG00000188976  chr1     955438 -0.000491  0.120386     0.996756
# 14101  ENSG00000188976  chr1     964972  0.036084  0.095284     0.705639
# 14102  ENSG00000188976  chr1     965011 -0.099198  0.125367     0.431758
# 14103  ENSG00000188976  chr1     965443 -0.116484  0.077793     0.136233
# 14104  ENSG00000188976  chr1     966469  0.126091  0.060150     0.036982
# 14105  ENSG00000188976  chr1     966507 -0.028623  0.093212     0.759340
# 14106  ENSG00000188976  chr1     987896  0.034374  0.064512     0.594646
# 14107  ENSG00000188976  chr1     804844  0.039798  0.073463     0.588646
# 14108  ENSG00000188976  chr1     821624  0.060054  0.067298     0.373174
# 14109  ENSG00000188976  chr1     866513 -0.052302  0.056995     0.359515
# 14110  ENSG00000188976  chr1     900685  0.054557  0.058940     0.355417
#
# ...

# %%
newestr
# Out:
#                      gene chrom         str.id  str.start  n.miss  \
# 0       ENSG00000237683.5  chr1      STR_35484      35484       7
# 1       ENSG00000237683.5  chr1      STR_36352      36352      17
# 2       ENSG00000237683.5  chr1      STR_40640      40640      14
# 3       ENSG00000237683.5  chr1      STR_43795      43795      25
# 4       ENSG00000237683.5  chr1      STR_44836      44836      12
# 5       ENSG00000237683.5  chr1      STR_46403      46403      12
# 6       ENSG00000237683.5  chr1      STR_49510      49510       4
# 7       ENSG00000237683.5  chr1      STR_50481      50481       2
# 8       ENSG00000237683.5  chr1      STR_51863      51863       9
# 9       ENSG00000237683.5  chr1      STR_61351      61351       7
# 10      ENSG00000237683.5  chr1      STR_61863      61863       6
# 11      ENSG00000237683.5  chr1      STR_62232      62232       9
# 12      ENSG00000237683.5  chr1      STR_71847      71847      31
# ...
