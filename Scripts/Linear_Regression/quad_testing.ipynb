# %%
import math
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm

def ZNorm(vals,m=None,sd=None):
    if m is None:
        m = np.mean(vals)
        sd = math.sqrt(np.var(vals))
    if sd == 0: return None
    return [(item-m)/sd for item in vals]


OUTDIR = '/storage/szfeupe/Runs/650GTEx_estr/Analysis_by_Tissue/Lung/QuadraticReg/'
STRGTFILE= '/storage/szfeupe/Runs/650GTEx_estr/Genotypes/Allele_Gentypes.table'
EXPRESSION='/storage/szfeupe/Runs/650GTEx_estr/Analysis_by_Tissue/Adipose-Subcutaneous/Corr_Expr.csv'
EXPRANNOT='/storage/resources/dbase/human/hg19/gencode_gene_annotations_hg19.csv'
distfromgene = 100000
CHROM='chr21'

# %%
# Load STR genotypes
print("Load STRs")
strgt = pd.read_csv(STRGTFILE, sep="\t", low_memory=False)
strgt = strgt[strgt["chrom"] == CHROM]
print("Load expression")
expr = pd.read_csv(EXPRESSION)
print("Load annotation")
expr_annot = pd.read_csv(EXPRANNOT)
expr_annot.index = expr_annot["probe.id"].values
expr_annot = expr_annot[expr_annot["gene.chr"] == CHROM]
expr_annot = expr_annot.loc[[item for item in expr.columns if item in expr_annot.index],:]
# Restrict to STR samples
str_samples = list(set(strgt.columns[2:].values))
samples_to_remove = []
for item in str_samples:
    if item not in expr.index: samples_to_remove.append(item) #str_samples.remove(item)
for item in samples_to_remove: str_samples.remove(item)
expr = expr.loc[str_samples,:]
strgt = strgt[['chrom','start']+str_samples]
print("There are %s samples"%str(strgt.shape))
# Out:
# Load STRs
# Load expression
# Load annotation
# There are (2345, 272) samples

# %%
    #MODEL 1
        qmod_ols = sm.OLS('expr ,X ,X2', data = data).fit()
        print(qmod_ols.fvalue, qmod_ols.f_pvalue)
    #MODEL 2
        lmod_ols = sm.OLS('expr ,X', missing='drop').fit()
        print(lmod_ols...fvalue, lmod_ols.f_pvalue)
    #MODEL 3
        mod_ols = sm.OLS('expr, X2', missing='drop').fit
        print(mod_ols.fvalue, mod_ols.f_pvalue)
        
        
    #F-Test and ANOVA
        sm.stats.anova_lm(model1 , model2)
        formula = 'expr ~ X + X2'
        mod_ols = ols(formula, data).fit()
        hypo_tested = '(X2 = 0)'
        f_test = mod_ols.f_test(hypo_tested)
        print('>>>> Is beta = 0 ? **** ',f_test)
        test2 = np.identity(len(mod_ols.params))[1:,:]
        print('***are alpha and beta significatly !=0 ? **** ', mod_ols.f_test(test2))

# %%
#expr_annot = expr_annot.loc[expr_annot.index == 'ENSG00000158109.10']
List_Genes_for_Quad_test = []
NORM=True; ALLELE=True
MINSAMPLES=150
#for i in range(150,expr_annot.shape[0],1):
for i in range(0,expr_annot.shape[0],1):
    gene = expr_annot.index.values[i]
    print(" Getting data for %s"%gene)
    start = expr_annot["gene.start"].values[i]
    end = expr_annot["gene.stop"].values[i]
    cis_strs = strgt[(strgt["start"] >= (start-distfromgene)) & (strgt["start"] <= (end+distfromgene))]
    print(gene, '\t',start,'\t',end,'\t',"%s STRs tested \n"%str(cis_strs.shape[0]))
    y = pd.DataFrame({"expr":list(expr.loc[:, gene])})
    y.index = str_samples
    print('#****\tTesting %s STRs for this gene'%str(cis_strs.shape[0]))
    for j in range(cis_strs.shape[0]):
        locus_str = cis_strs.iloc[[j],:][str_samples].transpose()
        locus_str.index = str_samples
        locus_str.columns = ["STR_%s"%(cis_strs["start"].values[j])]
        test_str=locus_str.columns[0]
        str_start = cis_strs["start"].values[j]
        locus_str['x1'] = locus_str[test_str].apply(lambda x: x.split(',')[0] )
        locus_str['x2'] = locus_str[test_str].apply(lambda x: x.split(',')[1] )
        samples_to_keep = [str_samples[k] for k in range(len(str_samples)) if (str(locus_str['x1'].values[k]) != "NA")and(str(locus_str['x2'].values[k]) != "NA")]   
        locus_str = locus_str.loc[samples_to_keep,:]        
        locus_y = y.loc[samples_to_keep,:]            
        Locus_data = locus_str.join(locus_y)
        locus_str = locus_str.join(locus_y)[['expr','x1','x2']]
        #print(locus_str.head(3), '\n...\n',Locus_detail.head(3))

    # Prepare table for regression
        data = Locus_data[['expr','x1','x2']]
        m = np.mean(list(locus_str["x1"].astype(int))+list(locus_str["x2"].astype(int))) 
        sd= math.sqrt(np.var(locus_str["x1"].astype(int) + locus_str["x2"].astype(int) ))
        data.loc[:,'x1'] =ZNorm(data['x1'].astype(int), sd, m)
        data.loc[:,'x2'] =ZNorm(data['x2'].astype(int), sd, m)       
        data.loc[:,'expr'] =ZNorm(data['expr'].astype(int))
        if data['x1'].isnull().all()  or data['x2'].isnull().all() or data['expr'].isnull().all():
            print ('One or more values are NULL! skipping STR...')
            continue
        else:
            n=1
        data['X']=data['x1']+data['x2']                          #alpha(x1+x2)
        data['X2']=data['x1']**2 + data['x2']**2                 #beta(sq(x1)+sq(x2))
    #REGRESSION    
    ###Each time we test if each coefficient is statistically different from 0
    #Decide of model
    #MODEL 1
        formula = 'expr ~ X + X2'
        qmod_ols = ols(formula, data).fit()
        hypo_tested = '(X2 = 0)'
        f_test = qmod_ols.f_test(hypo_tested)
        #print('>>>> Is beta = 0 ? **** ',qmod_ols.f_pvalue, '\t', f_test.pvalue) 
        
    #Results
        F = f_test.fvalue
        p_value = f_test.pvalue
        if p_value <=0.05:
    #MODEL 2
            lmod_ols = ols('expr ~ X', data=data, missing='drop').fit()
    #Which one is better?
            Anova_results = anova_lm(lmod_ols , qmod_ols)
            print('Adding X2 improve expression prediction model ? ****\n', Anova_results)
            if Anova_results["Pr(>F)"].values[1] <=0.05:
                test2 = np.identity(len(mod_ols.params))[1:,:]
                print('are alpha and beta significatly !=0 ? **** ', mod_ols.f_test(test2))
                List_Genes_for_Quad_test.append(gene+','+CHROM+','+str(str_start)+str(F[0][0])+','+str(str_start)+','+str(Anova_results["Pr(>F)"].values[1]))  

f=open(OUTDIR+'Candidates_genes_4_quad_model_anova.csv', 'w')
f.write('gene,chrom,str_start,F-stat,F_pvalue,anova\n')
f.write('\n'.join(List_Genes_for_Quad_test))
f.close()
print('\n'.join(List_Genes_for_Quad_test[:10]))
# Out:
#  Getting data for ENSG00000188992.7
# ENSG00000188992.7 	 15481134 	 15583166 	 24 STRs tested
#
# #****	Testing 24 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     231.0  232.981392      0.0       NaN       NaN       NaN
# 1     230.0  226.556328      1.0  6.425064  6.522725  0.011297
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# /usr/lib64/python3.4/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /usr/lib64/python3.4/site-packages/pandas/core/indexing.py:621: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
# /usr/lib64/python3.4/site-packages/scipy/stats/_distn_infrastructure.py:875: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /usr/lib64/python3.4/site-packages/scipy/stats/_distn_infrastructure.py:875: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /usr/lib64/python3.4/site-packages/scipy/stats/_distn_infrastructure.py:1814: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
#  Getting data for ENSG00000185272.9
# ENSG00000185272.9 	 15588451 	 15600693 	 19 STRs tested
#
# #****	Testing 19 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     264.0  265.980073      0.0       NaN       NaN       NaN
# 1     263.0  261.216759      1.0  4.763314  4.795831  0.029407
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff    ss_diff          F    Pr(>F)
# 0     264.0  265.096525      0.0        NaN        NaN       NaN
# 1     263.0  251.050962      1.0  14.045563  14.714076  0.000157
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff  ss_diff         F    Pr(>F)
# 0     257.0  257.676664      0.0      NaN       NaN       NaN
# 1     256.0  253.768544      1.0  3.90812  3.942485  0.048148
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000155304.4
# ENSG00000155304.4 	 15743436 	 15755805 	 15 STRs tested
#
# #****	Testing 15 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff  ss_diff   F  Pr(>F)
# 0     260.0  257.286357      0.0      NaN NaN     NaN
# 1     260.0  257.286357     -0.0     -0.0 NaN     NaN
# One or more values are NULL! skipping STR...
#  Getting data for ENSG00000155307.13
# ENSG00000155307.13 	 15857549 	 15955723 	 22 STRs tested
#
# #****	Testing 22 STRs for this gene
# One or more values are NULL! skipping STR...
#  Getting data for ENSG00000243440.2
# ENSG00000243440.2 	 15964251 	 16031142 	 24 STRs tested
#
# #****	Testing 24 STRs for this gene
# One or more values are NULL! skipping STR...
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     239.0  240.264512      0.0       NaN       NaN       NaN
# 1     238.0  232.362133      1.0  7.902379  8.094117  0.004828
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000180530.5
# ENSG00000180530.5 	 16333556 	 16437321 	 27 STRs tested
#
# #****	Testing 27 STRs for this gene
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
#  Getting data for ENSG00000155313.11
# ENSG00000155313.11 	 17102344 	 17252377 	 26 STRs tested
#
# #****	Testing 26 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff    ss_diff          F    Pr(>F)
# 0     248.0  249.524022      0.0        NaN        NaN       NaN
# 1     247.0  227.826165      1.0  21.697857  23.523948  0.000002
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff    ss_diff          F        Pr(>F)
# 0     246.0  245.665173      0.0        NaN        NaN           NaN
# 1     245.0  215.338111      1.0  30.327063  34.504484  1.379401e-08
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000154639.14
# ENSG00000154639.14 	 18884700 	 18965897 	 27 STRs tested
#
# #****	Testing 27 STRs for this gene
#  Getting data for ENSG00000154640.10
# ENSG00000154640.10 	 18965971 	 18985265 	 13 STRs tested
#
# #****	Testing 13 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff  ss_diff         F    Pr(>F)
# 0     267.0  268.263093      0.0      NaN       NaN       NaN
# 1     266.0  264.142604      1.0  4.12049  4.149464  0.042638
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000154642.6
# ENSG00000154642.6 	 19161284 	 19191703 	 17 STRs tested
#
# #****	Testing 17 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff  ss_diff         F    Pr(>F)
# 0     229.0  230.960895      0.0      NaN       NaN       NaN
# 1     228.0  224.027315      1.0  6.93358  7.056533  0.008456
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff    ss_diff          F    Pr(>F)
# 0     212.0  213.579398      0.0        NaN        NaN       NaN
# 1     211.0  194.846807      1.0  18.732591  20.285561  0.000011
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     256.0  257.299852      0.0       NaN       NaN       NaN
# 1     255.0  253.387689      1.0  3.912163  3.937056  0.048305
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000154645.9
# ENSG00000154645.9 	 19273580 	 19639690 	 34 STRs tested
#
# #****	Testing 34 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     247.0  248.817712      0.0       NaN       NaN       NaN
# 1     246.0  243.968784      1.0  4.848928  4.889299  0.027944
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff    ss_diff          F    Pr(>F)
# 0     226.0  227.844370      0.0        NaN        NaN       NaN
# 1     225.0  217.536086      1.0  10.308284  10.661973  0.001264
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff    ss_diff          F    Pr(>F)
# 0     255.0  254.560500      0.0        NaN        NaN       NaN
# 1     254.0  244.160416      1.0  10.400084  10.819204  0.001147
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000154654.10
# ENSG00000154654.10 	 22370633 	 22915650 	 65 STRs tested
#
# #****	Testing 65 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff       ss_diff    F  Pr(>F)
# 0     255.0  249.725335      0.0           NaN  NaN     NaN
# 1     255.0  249.725335     -0.0  5.684342e-14 -inf     NaN
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     246.0  247.089817      0.0       NaN       NaN       NaN
# 1     245.0  241.293281      1.0  5.796536  5.885582  0.015988
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     247.0  245.020079      0.0       NaN       NaN       NaN
# 1     246.0  240.869210      1.0  4.150868  4.239287  0.040552
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000154719.9
# ENSG00000154719.9 	 26957968 	 26979829 	 22 STRs tested
#
# #****	Testing 22 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff       ss_diff    F  Pr(>F)
# 0     267.0  261.196621      0.0           NaN  NaN     NaN
# 1     267.0  261.196621     -0.0  5.684342e-14 -inf     NaN
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff    ss_diff          F    Pr(>F)
# 0     247.0  248.607592      0.0        NaN        NaN       NaN
# 1     246.0  235.045534      1.0  13.562058  14.194127  0.000206
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff    ss_diff          F    Pr(>F)
# 0     242.0  243.153917      0.0        NaN        NaN       NaN
# 1     241.0  225.296238      1.0  17.857679  19.102408  0.000018
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     252.0  249.772731      0.0       NaN       NaN       NaN
# 1     251.0  245.739877      1.0  4.032854  4.119178  0.043455
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000154721.10
# ENSG00000154721.10 	 27011584 	 27089874 	 26 STRs tested
#
# #****	Testing 26 STRs for this gene
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
#  Getting data for ENSG00000154723.8
# ENSG00000154723.8 	 27089973 	 27107984 	 20 STRs tested
#
# #****	Testing 20 STRs for this gene
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     248.0  249.506405      0.0       NaN       NaN       NaN
# 1     247.0  244.439970      1.0  5.066436  5.119497  0.024528
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
#  Getting data for ENSG00000154727.6
# ENSG00000154727.6 	 27106881 	 27144771 	 18 STRs tested
#
# #****	Testing 18 STRs for this gene
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
#  Getting data for ENSG00000142192.16
# ENSG00000142192.16 	 27252861 	 27543446 	 43 STRs tested
#
# #****	Testing 43 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff    ss_diff          F    Pr(>F)
# 0     259.0  259.157697      0.0        NaN        NaN       NaN
# 1     258.0  239.878040      1.0  19.279657  20.736169  0.000008
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000166265.7
# ENSG00000166265.7 	 27838528 	 27945603 	 24 STRs tested
#
# #****	Testing 24 STRs for this gene
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
#  Getting data for ENSG00000154734.10
# ENSG00000154734.10 	 28208066 	 28217728 	 11 STRs tested
#
# #****	Testing 11 STRs for this gene
#  Getting data for ENSG00000154736.5
# ENSG00000154736.5 	 28290231 	 28338832 	 13 STRs tested
#
# #****	Testing 13 STRs for this gene
#  Getting data for ENSG00000156239.7
# ENSG00000156239.7 	 30244513 	 30257693 	 13 STRs tested
#
# #****	Testing 13 STRs for this gene
#  Getting data for ENSG00000198862.9
# ENSG00000198862.9 	 30300466 	 30365270 	 13 STRs tested
#
# #****	Testing 13 STRs for this gene
# One or more values are NULL! skipping STR...
#  Getting data for ENSG00000156253.2
# ENSG00000156253.2 	 30376705 	 30391699 	 9 STRs tested
#
# #****	Testing 9 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff    ss_diff          F        Pr(>F)
# 0     263.0  264.167400      0.0        NaN        NaN           NaN
# 1     262.0  236.064666      1.0  28.102734  31.190252  5.847275e-08
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     239.0  240.348217      0.0       NaN       NaN       NaN
# 1     238.0  236.145603      1.0  4.202614  4.235617  0.040673
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff    ss_diff          F    Pr(>F)
# 0     250.0  251.803123      0.0        NaN        NaN       NaN
# 1     249.0  229.719379      1.0  22.083744  23.937259  0.000002
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000156256.10
# ENSG00000156256.10 	 30398030 	 30426809 	 7 STRs tested
#
# #****	Testing 7 STRs for this gene
# One or more values are NULL! skipping STR...
#  Getting data for ENSG00000156261.8
# ENSG00000156261.8 	 30428126 	 30446118 	 7 STRs tested
#
# #****	Testing 7 STRs for this gene
#  Getting data for ENSG00000156265.11
# ENSG00000156265.11 	 30449792 	 30548210 	 12 STRs tested
#
# #****	Testing 12 STRs for this gene
#  Getting data for ENSG00000156273.11
# ENSG00000156273.11 	 30591182 	 31003071 	 35 STRs tested
#
# #****	Testing 35 STRs for this gene
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
#  Getting data for ENSG00000171189.12
# ENSG00000171189.12 	 30909254 	 31312351 	 35 STRs tested
#
# #****	Testing 35 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     246.0  247.934416      0.0       NaN       NaN       NaN
# 1     245.0  242.452888      1.0  5.481528  5.539115  0.019387
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     265.0  263.952835      0.0       NaN       NaN       NaN
# 1     264.0  259.118542      1.0  4.834294  4.925365  0.027315
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff        F    Pr(>F)
# 0     220.0  221.497494      0.0       NaN      NaN       NaN
# 1     219.0  215.146240      1.0  6.351254  6.46502  0.011692
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff          F    Pr(>F)
# 0     227.0  228.950989      0.0       NaN        NaN       NaN
# 1     226.0  216.444079      1.0  12.50691  13.059085  0.000372
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000186971.2
# ENSG00000186971.2 	 31802572 	 31803216 	 9 STRs tested
#
# #****	Testing 9 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff  ss_diff   F  Pr(>F)
# 0     250.0  247.937323      0.0      NaN NaN     NaN
# 1     250.0  247.937323     -0.0     -0.0 NaN     NaN
#  Getting data for ENSG00000156299.8
# ENSG00000156299.8 	 32490734 	 32932290 	 64 STRs tested
#
# #****	Testing 64 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff        F    Pr(>F)
# 0     266.0  262.022996      0.0       NaN      NaN       NaN
# 1     265.0  255.670981      1.0  6.352015  6.58379  0.010842
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     267.0  268.833024      0.0       NaN       NaN       NaN
# 1     266.0  263.863489      1.0  4.969534  5.009773  0.026032
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000142168.10
# ENSG00000142168.10 	 33031935 	 33041244 	 20 STRs tested
#
# #****	Testing 20 STRs for this gene
#  Getting data for ENSG00000156304.10
# ENSG00000156304.10 	 33043346 	 33104388 	 26 STRs tested
#
# #****	Testing 26 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff  ss_diff   F  Pr(>F)
# 0     264.0  260.480561      0.0      NaN NaN     NaN
# 1     264.0  260.480561     -0.0     -0.0 NaN     NaN
#  Getting data for ENSG00000142149.4
# ENSG00000142149.4 	 33245628 	 33416946 	 34 STRs tested
#
# #****	Testing 34 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff    ss_diff          F    Pr(>F)
# 0     240.0  236.402586      0.0        NaN        NaN       NaN
# 1     239.0  218.910917      1.0  17.491669  19.096849  0.000019
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff  ss_diff         F    Pr(>F)
# 0     256.0  257.993109      0.0      NaN       NaN       NaN
# 1     255.0  253.247218      1.0  4.74589  4.778738  0.029723
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     255.0  256.607931      0.0       NaN       NaN       NaN
# 1     254.0  249.836740      1.0  6.771191  6.884026  0.009223
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     267.0  266.149361      0.0       NaN       NaN       NaN
# 1     266.0  258.242488      1.0  7.906873  8.144392  0.004659
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000159055.3
# ENSG00000159055.3 	 33640530 	 33651380 	 15 STRs tested
#
# #****	Testing 15 STRs for this gene
#  Getting data for ENSG00000170262.8
# ENSG00000170262.8 	 33664124 	 33671388 	 16 STRs tested
#
# #****	Testing 16 STRs for this gene
#  Getting data for ENSG00000142207.5
# ENSG00000142207.5 	 33683329 	 33765335 	 25 STRs tested
#
# #****	Testing 25 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff       ss_diff    F  Pr(>F)
# 0     256.0  251.487057      0.0           NaN  NaN     NaN
# 1     256.0  251.487057     -0.0  5.684342e-14 -inf     NaN
# One or more values are NULL! skipping STR...
#  Getting data for ENSG00000256073.2
# ENSG00000256073.2 	 33765439 	 33766254 	 21 STRs tested
#
# #****	Testing 21 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff  ss_diff   F  Pr(>F)
# 0     256.0  244.073308      0.0      NaN NaN     NaN
# 1     256.0  244.073308     -0.0     -0.0 NaN     NaN
# One or more values are NULL! skipping STR...
#  Getting data for ENSG00000166979.8
# ENSG00000166979.8 	 33784350 	 33887707 	 25 STRs tested
#
# #****	Testing 25 STRs for this gene
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
#  Getting data for ENSG00000242220.2
# ENSG00000242220.2 	 33948862 	 33959683 	 8 STRs tested
#
# #****	Testing 8 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     234.0  235.246493      0.0       NaN       NaN       NaN
# 1     233.0  225.396168      1.0  9.850325  10.18263  0.001613
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000159082.13
# ENSG00000159082.13 	 34001069 	 34100359 	 15 STRs tested
#
# #****	Testing 15 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff          F    Pr(>F)
# 0     216.0  208.872802      0.0       NaN        NaN       NaN
# 1     215.0  199.361880      1.0  9.510921  10.256966  0.001568
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff          F    Pr(>F)
# 0     220.0  221.842064      0.0       NaN        NaN       NaN
# 1     219.0  212.039712      1.0  9.802352  10.124118  0.001676
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000159086.10
# ENSG00000159086.10 	 34106210 	 34144169 	 12 STRs tested
#
# #****	Testing 12 STRs for this gene
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
#  Getting data for ENSG00000205930.4
# ENSG00000205930.4 	 34144411 	 34266043 	 26 STRs tested
#
# #****	Testing 26 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     244.0  237.725852      0.0       NaN       NaN       NaN
# 1     243.0  232.013179      1.0  5.712673  5.983193  0.015153
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff    ss_diff          F    Pr(>F)
# 0     247.0  248.864341      0.0        NaN        NaN       NaN
# 1     246.0  235.373185      1.0  13.491156  14.100265  0.000216
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff  ss_diff         F    Pr(>F)
# 0     236.0  236.968108      0.0      NaN       NaN       NaN
# 1     235.0  229.346838      1.0  7.62127  7.809126  0.005627
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000205929.5
# ENSG00000205929.5 	 34162985 	 34186053 	 17 STRs tested
#
# #****	Testing 17 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff        F    Pr(>F)
# 0     252.0  249.287127      0.0       NaN      NaN       NaN
# 1     251.0  244.229761      1.0  5.057366  5.19756  0.023458
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000184221.8
# ENSG00000184221.8 	 34442450 	 34444726 	 13 STRs tested
#
# #****	Testing 13 STRs for this gene
#  Getting data for ENSG00000159110.15
# ENSG00000159110.15 	 34602206 	 34636177 	 20 STRs tested
#
# #****	Testing 20 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff  ss_diff         F    Pr(>F)
# 0     267.0  266.021186      0.0      NaN       NaN       NaN
# 1     266.0  256.764536      1.0  9.25665  9.589598  0.002166
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000243646.4
# ENSG00000243646.4 	 34638663 	 34669539 	 21 STRs tested
#
# #****	Testing 21 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff        F    Pr(>F)
# 0     254.0  253.544195      0.0       NaN      NaN       NaN
# 1     253.0  247.671034      1.0  5.873161  5.99953  0.014989
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     263.0  264.938074      0.0       NaN       NaN       NaN
# 1     262.0  259.516645      1.0  5.421429  5.473307  0.020061
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000142166.8
# ENSG00000142166.8 	 34696734 	 34732168 	 23 STRs tested
#
# #****	Testing 23 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     259.0  260.999817      0.0       NaN       NaN       NaN
# 1     258.0  253.441629      1.0  7.558188  7.694129  0.005945
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     220.0  220.621786      0.0       NaN       NaN       NaN
# 1     219.0  214.226652      1.0  6.395134  6.537629  0.011238
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000159128.10
# ENSG00000159128.10 	 34775202 	 34851655 	 20 STRs tested
#
# #****	Testing 20 STRs for this gene
#  Getting data for ENSG00000142188.12
# ENSG00000142188.12 	 34804792 	 34852318 	 18 STRs tested
#
# #****	Testing 18 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid        ssr  df_diff  ss_diff         F    Pr(>F)
# 0     223.0  219.38502      0.0      NaN       NaN       NaN
# 1     222.0  215.40325      1.0  3.98177  4.103712  0.043986
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid        ssr  df_diff       ss_diff    F  Pr(>F)
# 0     268.0  256.88814      0.0           NaN  NaN     NaN
# 1     268.0  256.88814     -0.0  5.684342e-14 -inf     NaN
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     260.0  261.741990      0.0       NaN       NaN       NaN
# 1     259.0  257.270954      1.0  4.471036  4.501085  0.034823
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000177692.7
# ENSG00000177692.7 	 34860497 	 34864027 	 15 STRs tested
#
# #****	Testing 15 STRs for this gene
#  Getting data for ENSG00000159131.12
# ENSG00000159131.12 	 34876238 	 34915797 	 14 STRs tested
#
# #****	Testing 14 STRs for this gene
#  Getting data for ENSG00000159140.13
# ENSG00000159140.13 	 34915199 	 34949812 	 10 STRs tested
#
# #****	Testing 10 STRs for this gene
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
#  Getting data for ENSG00000159147.13
# ENSG00000159147.13 	 34931848 	 34961014 	 9 STRs tested
#
# #****	Testing 9 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff    ss_diff          F        Pr(>F)
# 0     268.0  266.367713      0.0        NaN        NaN           NaN
# 1     267.0  235.730146      1.0  30.637567  34.701673  1.153122e-08
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000205758.7
# ENSG00000205758.7 	 34961647 	 35016232 	 10 STRs tested
#
# #****	Testing 10 STRs for this gene
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
#  Getting data for ENSG00000205726.9
# ENSG00000205726.9 	 35014706 	 35272165 	 29 STRs tested
#
# #****	Testing 29 STRs for this gene
#  Getting data for ENSG00000241837.2
# ENSG00000241837.2 	 35275757 	 35288284 	 23 STRs tested
#
# #****	Testing 23 STRs for this gene
#  Getting data for ENSG00000243927.1
# ENSG00000243927.1 	 35496253 	 35515334 	 20 STRs tested
#
# #****	Testing 20 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     254.0  252.115589      0.0       NaN       NaN       NaN
# 1     253.0  246.338878      1.0  5.776711  5.932916  0.015552
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff    ss_diff          F        Pr(>F)
# 0     264.0  265.584712      0.0        NaN        NaN           NaN
# 1     263.0  228.355680      1.0  37.229032  42.877127  3.043885e-10
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000159197.3
# ENSG00000159197.3 	 35736323 	 35743688 	 13 STRs tested
#
# #****	Testing 13 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     226.0  227.615764      0.0       NaN       NaN       NaN
# 1     225.0  220.781749      1.0  6.834015  6.964586  0.008895
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000205670.6
# ENSG00000205670.6 	 35747779 	 35780164 	 16 STRs tested
#
# #****	Testing 16 STRs for this gene
#  Getting data for ENSG00000222018.1
# ENSG00000222018.1 	 35772615 	 35773370 	 16 STRs tested
#
# #****	Testing 16 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     260.0  260.454215      0.0       NaN       NaN       NaN
# 1     259.0  251.873834      1.0  8.580382  8.823143  0.003254
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000243627.4
# ENSG00000243627.4 	 35791013 	 35796264 	 18 STRs tested
#
# #****	Testing 18 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     226.0  227.926728      0.0       NaN       NaN       NaN
# 1     225.0  222.176079      1.0  5.750649  5.823742  0.016612
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid        ssr  df_diff   ss_diff          F    Pr(>F)
# 0     221.0  219.49589      0.0       NaN        NaN       NaN
# 1     220.0  209.82114      1.0  9.674751  10.144093  0.001658
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000180509.7
# ENSG00000180509.7 	 35818988 	 35884573 	 20 STRs tested
#
# #****	Testing 20 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     236.0  237.678462      0.0       NaN       NaN       NaN
# 1     235.0  233.261959      1.0  4.416503  4.449411  0.035971
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000159200.13
# ENSG00000159200.13 	 35885440 	 35987441 	 19 STRs tested
#
# #****	Testing 19 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     226.0  222.710050      0.0       NaN       NaN       NaN
# 1     225.0  214.646736      1.0  8.063313  8.452239  0.004011
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff    ss_diff          F    Pr(>F)
# 0     236.0  231.054787      0.0        NaN        NaN       NaN
# 1     235.0  212.477573      1.0  18.577213  20.546381  0.000009
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000159212.8
# ENSG00000159212.8 	 36041688 	 36090525 	 8 STRs tested
#
# #****	Testing 8 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     243.0  241.824697      0.0       NaN       NaN       NaN
# 1     242.0  235.712997      1.0  6.111699  6.274712  0.012906
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000159216.14
# ENSG00000159216.14 	 36160098 	 37376965 	 102 STRs tested
#
# #****	Testing 102 STRs for this gene
# One or more values are NULL! skipping STR...
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff          F    Pr(>F)
# 0     237.0  235.345274      0.0       NaN        NaN       NaN
# 1     236.0  225.476487      1.0  9.868787  10.329386  0.001492
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff  ss_diff         F    Pr(>F)
# 0     262.0  259.801046      0.0      NaN       NaN       NaN
# 1     261.0  252.296516      1.0  7.50453  7.763414  0.005723
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff        F    Pr(>F)
# 0     243.0  241.122177      0.0       NaN      NaN       NaN
# 1     242.0  237.289636      1.0  3.832541  3.90862  0.049174
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
#  Getting data for ENSG00000185917.9
# ENSG00000185917.9 	 37406839 	 37451687 	 22 STRs tested
#
# #****	Testing 22 STRs for this gene
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
#  Getting data for ENSG00000159228.8
# ENSG00000159228.8 	 37443248 	 37445464 	 17 STRs tested
#
# #****	Testing 17 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     260.0  261.237557      0.0       NaN       NaN       NaN
# 1     259.0  252.679093      1.0  8.558464  8.772558  0.003342
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000159231.5
# ENSG00000159231.5 	 37507210 	 37518864 	 21 STRs tested
#
# #****	Testing 21 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff        F    Pr(>F)
# 0     258.0  259.915021      0.0       NaN      NaN       NaN
# 1     257.0  254.926807      1.0  4.988213  5.02878  0.025782
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     220.0  216.631822      0.0       NaN       NaN       NaN
# 1     219.0  211.340115      1.0  5.291707  5.483502  0.020095
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000142197.8
# ENSG00000142197.8 	 37529080 	 37666572 	 37 STRs tested
#
# #****	Testing 37 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff    ss_diff          F        Pr(>F)
# 0     254.0  252.650816      0.0        NaN        NaN           NaN
# 1     253.0  228.347707      1.0  24.303109  26.926859  4.337465e-07
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000159256.8
# ENSG00000159256.8 	 37705944 	 37757127 	 25 STRs tested
#
# #****	Testing 25 STRs for this gene
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
#  Getting data for ENSG00000159259.7
# ENSG00000159259.7 	 37757676 	 37791313 	 19 STRs tested
#
# #****	Testing 19 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     261.0  262.252936      0.0       NaN       NaN       NaN
# 1     260.0  257.723083      1.0  4.529853  4.569873  0.033472
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000159261.6
# ENSG00000159261.6 	 37833051 	 37948867 	 22 STRs tested
#
# #****	Testing 22 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     258.0  251.354596      0.0       NaN       NaN       NaN
# 1     257.0  244.754244      1.0  6.600352  6.930587  0.008986
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     205.0  206.492486      0.0       NaN       NaN       NaN
# 1     204.0  201.707981      1.0  4.784505  4.838872  0.028948
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# ...
#  Getting data for ENSG00000160214.8
# ENSG00000160214.8 	 45209394 	 45225174 	 19 STRs tested
#
# #****	Testing 19 STRs for this gene
#  Getting data for ENSG00000160216.14
# ENSG00000160216.14 	 45285067 	 45406417 	 23 STRs tested
#
# #****	Testing 23 STRs for this gene
#  Getting data for ENSG00000160218.8
# ENSG00000160218.8 	 45432200 	 45526433 	 11 STRs tested
#
# #****	Testing 11 STRs for this gene
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
#  Getting data for ENSG00000241945.3
# ENSG00000241945.3 	 45527171 	 45551063 	 8 STRs tested
#
# #****	Testing 8 STRs for this gene
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
#  Getting data for ENSG00000160221.12
# ENSG00000160221.12 	 45553487 	 45565605 	 6 STRs tested
#
# #****	Testing 6 STRs for this gene
#  Getting data for ENSG00000267913.1
# ENSG00000267913.1 	 45587818 	 45593580 	 5 STRs tested
#
# #****	Testing 5 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff    ss_diff          F    Pr(>F)
# 0     247.0  248.523073      0.0        NaN        NaN       NaN
# 1     246.0  237.381068      1.0  11.142004  11.546553  0.000792
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000160223.12
# ENSG00000160223.12 	 45642874 	 45660849 	 6 STRs tested
#
# #****	Testing 6 STRs for this gene
#  Getting data for ENSG00000160224.12
# ENSG00000160224.12 	 45705763 	 45718102 	 7 STRs tested
#
# #****	Testing 7 STRs for this gene
#  Getting data for ENSG00000141959.12
# ENSG00000141959.12 	 45719934 	 45747259 	 6 STRs tested
#
# #****	Testing 6 STRs for this gene
#  Getting data for ENSG00000160226.11
# ENSG00000160226.11 	 45749115 	 45759258 	 3 STRs tested
#
# #****	Testing 3 STRs for this gene
#  Getting data for ENSG00000142185.12
# ENSG00000142185.12 	 45770046 	 45862964 	 4 STRs tested
#
# #****	Testing 4 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     218.0  219.245824      0.0       NaN       NaN       NaN
# 1     217.0  214.992079      1.0  4.253744  4.293472  0.039441
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000160233.6
# ENSG00000160233.6 	 45875369 	 45878739 	 2 STRs tested
#
# #****	Testing 2 STRs for this gene
#  Getting data for ENSG00000269430.1
# ENSG00000269430.1 	 45879814 	 45882078 	 1 STRs tested
#
# #****	Testing 1 STRs for this gene
#  Getting data for ENSG00000175894.10
# ENSG00000175894.10 	 45917775 	 46131495 	 12 STRs tested
#
# #****	Testing 12 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     221.0  222.282017      0.0       NaN       NaN       NaN
# 1     220.0  218.349208      1.0  3.932809  3.962542  0.047761
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000182912.6
# ENSG00000182912.6 	 45937099 	 45945835 	 1 STRs tested
#
# #****	Testing 1 STRs for this gene
#  Getting data for ENSG00000184787.14
# ENSG00000184787.14 	 46188955 	 46221934 	 16 STRs tested
#
# #****	Testing 16 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff       ss_diff    F  Pr(>F)
# 0     265.0  261.058832      0.0           NaN  NaN     NaN
# 1     265.0  261.058832     -0.0  5.684342e-14 -inf     NaN
#  Getting data for ENSG00000184900.11
# ENSG00000184900.11 	 46225532 	 46238694 	 12 STRs tested
#
# #****	Testing 12 STRs for this gene
#  Getting data for ENSG00000183255.7
# ENSG00000183255.7 	 46269500 	 46293752 	 9 STRs tested
#
# #****	Testing 9 STRs for this gene
#  Getting data for ENSG00000160255.12
# ENSG00000160255.12 	 46305868 	 46351904 	 12 STRs tested
#
# #****	Testing 12 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     241.0  242.049991      0.0       NaN       NaN       NaN
# 1     240.0  237.835926      1.0  4.214065  4.252409  0.040271
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000183250.7
# ENSG00000183250.7 	 46352729 	 46359828 	 10 STRs tested
#
# #****	Testing 10 STRs for this gene
#  Getting data for ENSG00000160256.8
# ENSG00000160256.8 	 46359925 	 46396904 	 12 STRs tested
#
# #****	Testing 12 STRs for this gene
#  Getting data for ENSG00000268856.1
# ENSG00000268856.1 	 46492796 	 46492927 	 12 STRs tested
#
# #****	Testing 12 STRs for this gene
#  Getting data for ENSG00000197381.11
# ENSG00000197381.11 	 46494484 	 46646478 	 20 STRs tested
#
# #****	Testing 20 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     259.0  259.553468      0.0       NaN       NaN       NaN
# 1     258.0  255.410931      1.0  4.142536  4.184529  0.041809
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     245.0  245.801186      0.0       NaN       NaN       NaN
# 1     244.0  237.794758      1.0  8.006428  8.215356  0.004516
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     266.0  267.496719      0.0       NaN       NaN       NaN
# 1     265.0  263.113870      1.0  4.382849  4.414267  0.036584
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000186866.12
# ENSG00000186866.12 	 46683843 	 46707813 	 11 STRs tested
#
# #****	Testing 11 STRs for this gene
# One or more values are NULL! skipping STR...
#  Getting data for ENSG00000182871.10
# ENSG00000182871.10 	 46825052 	 46933634 	 10 STRs tested
#
# #****	Testing 10 STRs for this gene
#  Getting data for ENSG00000173638.14
# ENSG00000173638.14 	 46913490 	 46964325 	 6 STRs tested
#
# #****	Testing 6 STRs for this gene
#  Getting data for ENSG00000183570.12
# ENSG00000183570.12 	 47063608 	 47362368 	 23 STRs tested
#
# #****	Testing 23 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff       ss_diff    F  Pr(>F)
# 0     264.0  261.676213      0.0           NaN  NaN     NaN
# 1     264.0  261.676213     -0.0  5.684342e-14 -inf     NaN
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff    ss_diff          F    Pr(>F)
# 0     248.0  249.084792      0.0        NaN        NaN       NaN
# 1     247.0  235.426368      1.0  13.658424  14.329876  0.000193
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000268040.1
# ENSG00000268040.1 	 47347679 	 47352477 	 7 STRs tested
#
# #****	Testing 7 STRs for this gene
#  Getting data for ENSG00000142156.10
# ENSG00000142156.10 	 47401651 	 47424964 	 6 STRs tested
#
# #****	Testing 6 STRs for this gene
# One or more values are NULL! skipping STR...
#  Getting data for ENSG00000142173.10
# ENSG00000142173.10 	 47518011 	 47552763 	 14 STRs tested
#
# #****	Testing 14 STRs for this gene
# One or more values are NULL! skipping STR...
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff  ss_diff   F  Pr(>F)
# 0     265.0  255.386307      0.0      NaN NaN     NaN
# 1     265.0  255.386307     -0.0     -0.0 NaN     NaN
# One or more values are NULL! skipping STR...
#  Getting data for ENSG00000160282.9
# ENSG00000160282.9 	 47556176 	 47575481 	 12 STRs tested
#
# #****	Testing 12 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff       ss_diff    F  Pr(>F)
# 0     267.0  253.982049      0.0           NaN  NaN     NaN
# 1     267.0  253.982049     -0.0  2.842171e-14 -inf     NaN
#  Getting data for ENSG00000160284.10
# ENSG00000160284.10 	 47581062 	 47604390 	 13 STRs tested
#
# #****	Testing 13 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F   Pr(>F)
# 0     248.0  248.593503      0.0       NaN       NaN      NaN
# 1     247.0  240.337826      1.0  8.255677  8.484524  0.00391
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff  ss_diff   F  Pr(>F)
# 0     267.0  237.103955      0.0      NaN NaN     NaN
# 1     267.0  237.103955     -0.0     -0.0 NaN     NaN
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     252.0  252.672449      0.0       NaN       NaN       NaN
# 1     251.0  243.854731      1.0  8.817719  9.076089  0.002855
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000160285.10
# ENSG00000160285.10 	 47608055 	 47648738 	 18 STRs tested
#
# #****	Testing 18 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff    ss_diff          F        Pr(>F)
# 0     255.0  256.114058      0.0        NaN        NaN           NaN
# 1     254.0  226.597055      1.0  29.517003  33.086568  2.525515e-08
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000235878.4
# ENSG00000235878.4 	 47612391 	 47613673 	 14 STRs tested
#
# #****	Testing 14 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff    ss_diff          F    Pr(>F)
# 0     255.0  252.587303      0.0        NaN        NaN       NaN
# 1     254.0  238.694623      1.0  13.892679  14.783494  0.000152
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000160294.6
# ENSG00000160294.6 	 47656743 	 47706211 	 18 STRs tested
#
# #****	Testing 18 STRs for this gene
#  Getting data for ENSG00000182362.9
# ENSG00000182362.9 	 47706251 	 47717665 	 16 STRs tested
#
# #****	Testing 16 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff       ss_diff    F  Pr(>F)
# 0     259.0  245.880213      0.0           NaN  NaN     NaN
# 1     259.0  245.880213     -0.0 -2.842171e-14  inf     NaN
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff        F    Pr(>F)
# 0     232.0  212.634143      0.0       NaN      NaN       NaN
# 1     231.0  208.695074      1.0  3.939069  4.36007  0.037887
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     266.0  258.409898      0.0       NaN       NaN       NaN
# 1     265.0  254.504938      1.0  3.904959  4.065989  0.044764
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     267.0  267.866163      0.0       NaN       NaN       NaN
# 1     266.0  263.978966      1.0  3.887197  3.916957  0.048832
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     234.0  228.076729      0.0       NaN       NaN       NaN
# 1     233.0  221.601624      1.0  6.475105  6.808161  0.009662
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff       ss_diff    F  Pr(>F)
# 0     266.0  254.074934      0.0           NaN  NaN     NaN
# 1     266.0  254.074934     -0.0 -2.842171e-14  inf     NaN
#  Getting data for ENSG00000160298.13
# ENSG00000160298.13 	 47720095 	 47743789 	 14 STRs tested
#
# #****	Testing 14 STRs for this gene
# Adding X2 improve expression prediction model ? ****
#     df_resid         ssr  df_diff    ss_diff          F    Pr(>F)
# 0     266.0  267.061256      0.0        NaN        NaN       NaN
# 1     265.0  249.170982      1.0  17.890273  19.026784  0.000018
# are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
#  Getting data for ENSG00000160299.12
# ENSG00000160299.12 	 47744036 	 47865682 	 23 STRs tested
#
# #****	Testing 23 STRs for this gene
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
#  Getting data for ENSG00000160305.13
# ENSG00000160305.13 	 47878812 	 47989926 	 22 STRs tested
#
# #****	Testing 22 STRs for this gene
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
# One or more values are NULL! skipping STR...
#  Getting data for ENSG00000160307.5
# ENSG00000160307.5 	 48018875 	 48025121 	 13 STRs tested

# %%
	Testing 24 STRs for this gene
>>>> Is beta = 0  <F test: F=array([[6.52272507]]), p=0.011296858467019884, df_denom=230, df_num=1>
***are alpha and beta significatly !=0 ? ****  <F test: F=array([[3.2708079]]), p=0.03974951595111735, df_denom=230, df_num=2>
>>>> Is beta = 0  <F test: F=array([[0.10913066]]), p=0.7414083557571096, df_denom=254, df_num=1>
***are alpha and beta significatly !=0 ? ****  <F test: F=array([[0.08510146]]), p=0.9184452762288461, df_denom=254, df_num=2>
>>>> Is beta = 0  <F test: F=array([[0.46402663]]), p=0.49636867527929995, df_denom=254, df_num=1>
***are alpha and beta significatly !=0 ? ****  <F test: F=array([[0.840262]]), p=0.4327935250652042, df_denom=254, df_num=2>
>>>> Is beta = 0  <F test: F=array([[0.45108972]]), p=0.5024331417413783, df_denom=252, df_num=1>
***are alpha and beta significatly !=0 ? ****  <F test: F=array([[0.22712927]]), p=0.7969807122039558, df_denom=252, df_num=2>
>>>> Is beta = 0  <F test: F=array([[0.00806919]]), p=0.9284955682303655, df_denom=249, df_num=1>
***are alpha and beta significatly !=0 ? ****  <F test: F=array([[0.0169991]]), p=0.9831457110016488, df_denom=249, df_num=2>
>>>> Is beta = 0  <F test: F=array([[0.00506218]]), p=0.9433379406372907, df_denom=242, df_num=1>
***are alpha and beta significatly !=0 ? ****  <F test: F=array([[0.00316182]]), p=0.9968432121146652, df_denom=242, df_num=2>
>>>> Is beta = 0  <F test: F=array([[0.04177419]]), p=0.8382071114146905, df_denom=266, df_num=1>
***are alpha and beta significatly !=0 ? ****  <F test: F=array([[0.02271119]]), p=0.9775466582342074, df_denom=266, df_num=2>
>>>> Is beta = 0  <F test: F=array([[0.05949083]]), p=0.8075009686794087, df_denom=252, df_num=1>
***are alpha and beta significatly !=0 ? ****  <F test: F=array([[0.03419285]]), p=0.9663895993328824, df_denom=252, df_num=2>
>>>> Is beta = 0  <F test: F=array([[0.07700193]]), p=0.7816482306456368, df_denom=233, df_num=1>
***are alpha and beta significatly !=0 ? ****  <F test: F=array([[0.05098065]]), p=0.9503076525123617, df_denom=233, df_num=2>
>>>> Is beta = 0  <F test: F=array([[0.01558227]]), p=0.9007525400588421, df_denom=268, df_num=1>
***are alpha and beta significatly !=0 ? ****  <F test: F=array([[0.0079662]]), p=0.9920656855439975, df_denom=268, df_num=2>
>>>> Is beta = 0  <F test: F=array([[0.01290217]]), p=0.9096624435152846, df_denom=233, df_num=1>
***are alpha and beta significatly !=0 ? ****  <F test: F=array([[0.16328395]]), p=0.8494470894001349, df_denom=233, df_num=2>
>>>> Is beta = 0  <F test: F=array([[0.02571204]]), p=0.8727387975678107, df_denom=243, df_num=1>
***are alpha and beta significatly !=0 ? ****  <F test: F=array([[0.17673329]]), p=0.8381108724452975, df_denom=243, df_num=2>
>>>> Is beta = 0  <F test: F=array([[0.37752443]]), p=0.5395930680014236, df_denom=211, df_num=1>
***are alpha and beta significatly !=0 ? ****  <F test: F=array([[0.96357397]]), p=0.3831992359300672, df_denom=211, df_num=2>
>>>> Is beta = 0  <F test: F=array([[0.79748217]]), p=0.37266361794823344, df_denom=263, df_num=1>
***are alpha and beta significatly !=0 ? ****  <F test: F=array([[0.73212273]]), p=0.48186454814047475, df_denom=263, df_num=2>
>>>> Is beta = 0  <F test: F=array([[0.09959487]]), p=0.7526000531110633, df_denom=232, df_num=1>
***are alpha and beta significatly !=0 ? ****  <F test: F=array([[0.05545228]]), p=0.946069707478107, df_denom=232, df_num=2>
>>>> Is beta = 0  <F test: F=array([[1.62106483]]), p=0.20428099751945564, df_denom=221, df_num=1>
***are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.27495301]]), p=0.28149126229575955, df_denom=221, df_num=2>
>>>> Is beta = 0  <F test: F=array([[0.0125244]]), p=0.9109948645236097, df_denom=220, df_num=1>
***are alpha and beta significatly !=0 ? ****  <F test: F=array([[0.08480519]]), p=0.9187212535448299, df_denom=220, df_num=2>
>>>> Is beta = 0  <F test: F=array([[0.46730506]]), p=0.49484068675531523, df_denom=259, df_num=1>
***are alpha and beta significatly !=0 ? ****  <F test: F=array([[0.23402244]]), p=0.7915112061619995, df_denom=259, df_num=2>
>>>> Is beta = 0  <F test: F=array([[2.39828343e-06]]), p=0.9987655303195572, df_denom=265, df_num=1>
***are alpha and beta significatly !=0 ? ****  <F test: F=array([[0.00015523]]), p=0.9998447802626191, df_denom=265, df_num=2>
>>>> Is beta = 0  <F test: F=array([[0.01395513]]), p=0.906053359256373, df_denom=263, df_num=1>
***are alpha and beta significatly !=0 ? ****  <F test: F=array([[0.59454549]]), p=0.5525532466712586, df_denom=263, df_num=2>
>>>> Is beta = 0  <F test: F=array([[1.37307403]]), p=0.24237381426602309, df_denom=256, df_num=1>
***are alpha and beta significatly !=0 ? ****  <F test: F=array([[0.95306552]]), p=0.38692095496831014, df_denom=256, df_num=2>
>>>> Is beta = 0  <F test: F=array([[2.84616894]]), p=0.09279128677025261, df_denom=260, df_num=1>
***are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.6516116]]), p=0.19374585430774355, df_denom=260, df_num=2>
>>>> Is beta = 0  <F test: F=array([[0.23192216]]), p=0.6305522872240783, df_denom=234, df_num=1>
***are alpha and beta significatly !=0 ? ****  <F test: F=array([[0.14029507]]), p=0.8691748022216459, df_denom=234, df_num=2>
>>>> Is beta = 0  <F test: F=array([[0.34339139]]), p=0.5583865013828422, df_denom=260, df_num=1>
***are alpha and beta significatly !=0 ? ****  <F test: F=array([[1.46130967]]), p=0.23383079392298134, df_denom=260, df_num=2>
