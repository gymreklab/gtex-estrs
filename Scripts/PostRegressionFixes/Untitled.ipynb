# %%
import pandas as pd
import numpy as np
import subprocess
import collections
## 
SHORTEN = {
    "Artery-Aorta":"Artery A."     ,
    "Artery-Tibial": "Artery T.",
    "Adipose-Subcutaneous": "Adipose S.",    
    "Adipose-Visceral":"Adipose V.",
    "Brain-Caudate":"Caudate"   , 
    "Brain-Cerebellum":"Cerebellum",
    "Cells-Transformedfibroblasts": "Fibroblast",
    "Esophagus-Mucosa": "E. Mucosa",
    "Esophagus-Muscularis":"E Muscularis",
    "Heart-LeftVentricle":"Ventricule",
    "Lung": "Lung",
    "Muscle-Skeletal": "Muscle",
    "Nerve-Tibial":"Nerve",
    "Skin-NotSunExposed": "Skin Unexposed",
    "Skin-SunExposed":"Skin Leg",
    "Thyroid":"Thyroid",
    "WholeBlood": "Blood"
}

tissu = sorted(SHORTEN.keys())
#path = "/storage/szfeupe/Runs/GTEx_estr/Analysis_by_Tissue/"
path = "/storage/szfeupe/Runs/650GTEx_estr/Analysis_by_Tissue/WholeBlood/QuadraticReg/"

# %%
wb =  pd.read_csv(path+'Quad_Regression_1.tab', sep='\t')
wb['delta_aic[Lin-Quad]'].replace('', np.nan, inplace=True)
wbquad = wb.loc[wb['delta_aic[Lin-Quad]'].astype(float)<0]
wblin  = wb.loc[wb['delta_aic[Lin-Quad]'].astype(float)>0]
wb['anova_pva'].replace('None', np.nan, inplace=True)
wb.loc[wb['anova_pva'].astype(float)<1]
# Out:
#      chrom                gene         str.id  str.start               alpha  \
# 2     chr1   ENSG00000186827.6    STR_1209175    1209175   -0.00996696138905
# 3     chr1  ENSG00000078808.12    STR_1209175    1209175   1.17961196366e-16
# 6     chr1  ENSG00000160087.16    STR_1209175    1209175   1.17961196366e-16
# 7     chr1  ENSG00000160087.16    STR_1298161    1298161    6.1669419571e-16
# 9     chr1  ENSG00000162572.15    STR_1298161    1298161    -0.0270965471934
# 10    chr1  ENSG00000131584.14    STR_1209175    1209175   1.17961196366e-16
# 11    chr1  ENSG00000131584.14    STR_1298161    1298161    6.1669419571e-16
# 13    chr1   ENSG00000169972.7    STR_1298161    1298161    -0.0435991363604
# 14    chr1  ENSG00000127054.14    STR_1209175    1209175   1.17961196366e-16
# 15    chr1  ENSG00000127054.14    STR_1298161    1298161    6.1669419571e-16
# 16    chr1   ENSG00000224051.2    STR_1209175    1209175   1.17961196366e-16
# ...
