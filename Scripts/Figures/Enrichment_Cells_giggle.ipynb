# %%
"""
A. For each tissue, enrichment [how likely are eSTRs to fall in TF sites]
Fisher test at each tissue
    Background: All STRs
    Forground: eSTRs that fall within TFs 

"""

# Libraries
from collections import defaultdict
from matplotlib import gridspec
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import scipy.stats as ss
import seaborn.apionly as sns

#variables

SHORTEN = {
    "Artery-Aorta":"Artery.A"     ,
    "Artery-Tibial": "Artery.T",
    "Adipose-Subcutaneous": "Adipose.S",    
    "Adipose-Visceral(Omentum)":"Adipose.V",
    "Brain-Caudate(basalganglia)":"Caudate"   , 
    "Brain-Cerebellum":"Cerebellum",
    "Cells-Transformedfibroblasts": "Fibroblast",
    "Esophagus-Mucosa": "Mucosa",
    "Esophagus-Muscularis":"Muscularis",
    "Heart-LeftVentricle":"Ventricule",
    "Lung": "Lung",
    "Muscle-Skeletal": "Muscle",
    "Nerve-Tibial":"Nerve",
    "Skin-NotSunExposed(Suprapubic)": "SkinUnexposed",
    "Skin-SunExposed(Lowerleg)":"SkinLeg",
    "Thyroid":"Thyroid",
    "WholeBlood": "Blood"
}
TISSUES = sorted([item for item in list(SHORTEN.keys())])
regr='/storage/szfeupe/Runs/650GTEx_estr/Analysis_by_Tissue/'
feat='/storage/szfeupe/Runs/GTEx_estr/FEATURES/Allgencodefeatures_table'
motif='/storage/resources/dbase/human/hg19/hg19.hipstr_reference_withmotif.bed'
strand= '/storage/resources/dbase/human/hg19/hg19.hipstr_reference_withmotif_stranded.bed'

# %%
# On 
# Cont. Table by Tissues
TFs = '/storage/mgymrek/gtex/tfbs/enrichment/'
transfacts = os.listdir(TFs)
transfacts = [x for x in transfacts if '_roadmap_enrich.tab' in x]

# Fisher test at tissues
DATA=[]
for i in range (len(TISSUES)):
    # Data
    P=[]
    tis = TISSUES[i]
    data = pd.read_csv(TFs+tis+'_roadmap_enrich.tab', sep='\t')
    data = data.loc[data['AB']>=50]
    data[SHORTEN[tis]] = np.log10(data['pval'])
    #pvalues in tissue
    PV = data[['category',SHORTEN[tis]]]   
    DATA.append(PV)

pdata=PV
for i in range (len(TISSUES)-1):
    pdata = pd.merge(pdata, DATA[i], on='category')

##Cell types grouped
CELL = list(set([x.split('_')[0] for x in list(pdata['category']) ]))
CATEGORY = defaultdict(list)
for x in CELL:
    CATEGORY[x]=[l for l in list(pdata['category']) if x in l]
                
    
#Plot All Enhancers (Genic)
Cell = [x for x in list(pdata['category']) if 'Genic_enhancers' in x]
pdata1 = pdata.loc[pdata['category'].isin(Cell)]
pdata1.index=Cell
del pdata1['category']

#TSS
Cell = [x for x in list(pdata['category']) if 'Active_TSS' in x and 'Flanking' not in x]
pdata2 = pdata.loc[pdata['category'].isin(Cell)]
pdata2.index=Cell
del pdata2['category']

print(pdata.shape)


fig, ax = plt.subplots(figsize=(10, 20))
cmap = sns.diverging_palette(265, 15, s=80, l=55, n=9, as_cmap=True)    
sns.heatmap(pdata1, cmap=cmap,  annot_kws={"size": 5},
            vmin=-5, vmax=0, square=True, ax=ax, linewidths=0.5, cbar_kws={"shrink": 0.5},
           xticklabels=[SHORTEN[t] for t in TISSUES], 
           yticklabels=[x for x in list(pdata1.index)])
plt.title('Enrichment at Genic Enhancer - Log10(pvalues)')


fig, ax = plt.subplots(figsize=(10, 20))
sns.heatmap(pdata2, cmap=cmap,  annot_kws={"size": 5},
            vmin=-5, vmax=0, square=True, ax=ax, linewidths=0.5, cbar_kws={"shrink": 0.5},
           xticklabels=[SHORTEN[t] for t in TISSUES], 
           yticklabels=[x for x in list(pdata2.index)])
plt.title('Enrichment at Active Trnscription Starting sites [log10(pvalue)]')
plt.show()
# Out:
# (1632, 18)

# %%
list(pdata['category'])
# Out:
# ['4star_Active_TSS',
#  '4star_Bivalent_Enhancer',
#  '4star_Bivalent_Poised_TSS',
#  '4star_Enhancers',
#  '4star_Flanking_Active_TSS',
#  '4star_Flanking_Bivalent_TSS_Enh',
#  '4star_Genic_enhancers',
#  '4star_Heterochromatin',
#  '4star_Quiescent_Low',
#  '4star_Repressed_PolyComb',
#  '4star_Strong_transcription',
#  '4star_Weak_Repressed_PolyComb',
#  '4star_Weak_transcription',
#  '4star_ZNF_genes_and_repeats',
#  'A549_EtOH_0.02pct_Lung_Carcinoma_Active_TSS',
#  'A549_EtOH_0.02pct_Lung_Carcinoma_Bivalent_Enhancer',
#  'A549_EtOH_0.02pct_Lung_Carcinoma_Bivalent_Poised_TSS',
#  'A549_EtOH_0.02pct_Lung_Carcinoma_Enhancers',
#  'A549_EtOH_0.02pct_Lung_Carcinoma_Flanking_Active_TSS',
#  'A549_EtOH_0.02pct_Lung_Carcinoma_Genic_enhancers',
#  'A549_EtOH_0.02pct_Lung_Carcinoma_Heterochromatin',
#  'A549_EtOH_0.02pct_Lung_Carcinoma_Quiescent_Low',
#  'A549_EtOH_0.02pct_Lung_Carcinoma_Repressed_PolyComb',
#  'A549_EtOH_0.02pct_Lung_Carcinoma_Strong_transcription',
#  'A549_EtOH_0.02pct_Lung_Carcinoma_Transcr_at_gene_5_and_3',
#  'A549_EtOH_0.02pct_Lung_Carcinoma_Weak_Repressed_PolyComb',
#  'A549_EtOH_0.02pct_Lung_Carcinoma_Weak_transcription',
#  'A549_EtOH_0.02pct_Lung_Carcinoma_ZNF_genes_and_repeats',
#  'Adipose_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Active_TSS',
#  'Adipose_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Bivalent_Enhancer',
#  'Adipose_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Bivalent_Poised_TSS',
#  'Adipose_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Enhancers',
#  'Adipose_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Flanking_Active_TSS',
#  'Adipose_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Genic_enhancers',
#  'Adipose_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Heterochromatin',
#  'Adipose_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Quiescent_Low',
#  'Adipose_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Repressed_PolyComb',
#  'Adipose_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Strong_transcription',
#  'Adipose_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Weak_Repressed_PolyComb',
#  'Adipose_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Weak_transcription',
#  'Adipose_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_ZNF_genes_and_repeats',
#  'Adipose_Nuclei_Active_TSS',
#  'Adipose_Nuclei_Bivalent_Enhancer',
#  'Adipose_Nuclei_Enhancers',
#  'Adipose_Nuclei_Flanking_Active_TSS',
#  'Adipose_Nuclei_Flanking_Bivalent_TSS_Enh',
#  'Adipose_Nuclei_Genic_enhancers',
#  'Adipose_Nuclei_Heterochromatin',
#  'Adipose_Nuclei_Quiescent_Low',
#  'Adipose_Nuclei_Repressed_PolyComb',
#  'Adipose_Nuclei_Strong_transcription',
#  'Adipose_Nuclei_Weak_Repressed_PolyComb',
#  'Adipose_Nuclei_Weak_transcription',
#  'Adipose_Nuclei_ZNF_genes_and_repeats',
#  'Adult_Liver_Active_TSS',
#  'Adult_Liver_Bivalent_Enhancer',
#  'Adult_Liver_Enhancers',
#  'Adult_Liver_Flanking_Active_TSS',
#  'Adult_Liver_Genic_enhancers',
#  'Adult_Liver_Heterochromatin',
#  'Adult_Liver_Quiescent_Low',
#  'Adult_Liver_Repressed_PolyComb',
#  'Adult_Liver_Strong_transcription',
#  'Adult_Liver_Weak_Repressed_PolyComb',
#  'Adult_Liver_Weak_transcription',
#  'Adult_Liver_ZNF_genes_and_repeats',
#  'Aorta_Active_TSS',
#  'Aorta_Enhancers',
#  'Aorta_Heterochromatin',
#  'Aorta_Quiescent_Low',
#  'Aorta_Repressed_PolyComb',
#  'Aorta_Strong_transcription',
#  'Aorta_Weak_Repressed_PolyComb',
#  'Aorta_Weak_transcription',
#  'Aorta_ZNF_genes_and_repeats',
#  'Bone_Marrow_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Active_TSS',
#  'Bone_Marrow_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Bivalent_Poised_TSS',
#  'Bone_Marrow_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Enhancers',
#  'Bone_Marrow_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Flanking_Active_TSS',
#  'Bone_Marrow_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Genic_enhancers',
#  'Bone_Marrow_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Heterochromatin',
#  'Bone_Marrow_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Quiescent_Low',
#  'Bone_Marrow_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Repressed_PolyComb',
#  'Bone_Marrow_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Strong_transcription',
#  'Bone_Marrow_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Weak_Repressed_PolyComb',
#  'Bone_Marrow_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Weak_transcription',
#  'Bone_Marrow_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_ZNF_genes_and_repeats',
#  'Brain_Angular_Gyrus_Active_TSS',
#  'Brain_Angular_Gyrus_Enhancers',
#  'Brain_Angular_Gyrus_Flanking_Active_TSS',
#  'Brain_Angular_Gyrus_Genic_enhancers',
#  'Brain_Angular_Gyrus_Heterochromatin',
#  'Brain_Angular_Gyrus_Quiescent_Low',
#  'Brain_Angular_Gyrus_Repressed_PolyComb',
#  'Brain_Angular_Gyrus_Strong_transcription',
#  'Brain_Angular_Gyrus_Weak_Repressed_PolyComb',
#  'Brain_Angular_Gyrus_Weak_transcription',
#  'Brain_Angular_Gyrus_ZNF_genes_and_repeats',
#  'Brain_Anterior_Caudate_Active_TSS',
#  'Brain_Anterior_Caudate_Enhancers',
#  'Brain_Anterior_Caudate_Flanking_Active_TSS',
#  'Brain_Anterior_Caudate_Genic_enhancers',
#  'Brain_Anterior_Caudate_Heterochromatin',
#  'Brain_Anterior_Caudate_Quiescent_Low',
#  'Brain_Anterior_Caudate_Repressed_PolyComb',
#  'Brain_Anterior_Caudate_Strong_transcription',
#  'Brain_Anterior_Caudate_Weak_Repressed_PolyComb',
#  'Brain_Anterior_Caudate_Weak_transcription',
#  'Brain_Anterior_Caudate_ZNF_genes_and_repeats',
#  'Brain_Cingulate_Gyrus_Active_TSS',
#  'Brain_Cingulate_Gyrus_Bivalent_Poised_TSS',
#  'Brain_Cingulate_Gyrus_Enhancers',
#  'Brain_Cingulate_Gyrus_Flanking_Active_TSS',
#  'Brain_Cingulate_Gyrus_Flanking_Bivalent_TSS_Enh',
#  'Brain_Cingulate_Gyrus_Genic_enhancers',
#  'Brain_Cingulate_Gyrus_Heterochromatin',
#  'Brain_Cingulate_Gyrus_Quiescent_Low',
#  'Brain_Cingulate_Gyrus_Repressed_PolyComb',
#  'Brain_Cingulate_Gyrus_Strong_transcription',
#  'Brain_Cingulate_Gyrus_Weak_Repressed_PolyComb',
#  'Brain_Cingulate_Gyrus_Weak_transcription',
#  'Brain_Cingulate_Gyrus_ZNF_genes_and_repeats',
#  'Brain_Germinal_Matrix_Active_TSS',
#  'Brain_Germinal_Matrix_Bivalent_Enhancer',
#  'Brain_Germinal_Matrix_Bivalent_Poised_TSS',
#  'Brain_Germinal_Matrix_Enhancers',
#  'Brain_Germinal_Matrix_Flanking_Active_TSS',
#  'Brain_Germinal_Matrix_Flanking_Bivalent_TSS_Enh',
#  'Brain_Germinal_Matrix_Genic_enhancers',
#  'Brain_Germinal_Matrix_Heterochromatin',
#  'Brain_Germinal_Matrix_Quiescent_Low',
#  'Brain_Germinal_Matrix_Repressed_PolyComb',
#  'Brain_Germinal_Matrix_Strong_transcription',
#  'Brain_Germinal_Matrix_Weak_Repressed_PolyComb',
#  'Brain_Germinal_Matrix_Weak_transcription',
#  'Brain_Germinal_Matrix_ZNF_genes_and_repeats',
#  'Brain_Hippocampus_Middle_Active_TSS',
#  'Brain_Hippocampus_Middle_Bivalent_Enhancer',
#  'Brain_Hippocampus_Middle_Bivalent_Poised_TSS',
#  'Brain_Hippocampus_Middle_Enhancers',
#  'Brain_Hippocampus_Middle_Flanking_Active_TSS',
#  'Brain_Hippocampus_Middle_Flanking_Bivalent_TSS_Enh',
#  'Brain_Hippocampus_Middle_Genic_enhancers',
#  'Brain_Hippocampus_Middle_Heterochromatin',
#  'Brain_Hippocampus_Middle_Quiescent_Low',
#  'Brain_Hippocampus_Middle_Repressed_PolyComb',
#  'Brain_Hippocampus_Middle_Strong_transcription',
#  'Brain_Hippocampus_Middle_Weak_Repressed_PolyComb',
#  'Brain_Hippocampus_Middle_Weak_transcription',
#  'Brain_Hippocampus_Middle_ZNF_genes_and_repeats',
#  'Brain_Inferior_Temporal_Lobe_Active_TSS',
#  'Brain_Inferior_Temporal_Lobe_Bivalent_Enhancer',
#  'Brain_Inferior_Temporal_Lobe_Bivalent_Poised_TSS',
#  'Brain_Inferior_Temporal_Lobe_Enhancers',
#  'Brain_Inferior_Temporal_Lobe_Flanking_Active_TSS',
#  'Brain_Inferior_Temporal_Lobe_Genic_enhancers',
#  'Brain_Inferior_Temporal_Lobe_Heterochromatin',
#  'Brain_Inferior_Temporal_Lobe_Quiescent_Low',
#  'Brain_Inferior_Temporal_Lobe_Repressed_PolyComb',
#  'Brain_Inferior_Temporal_Lobe_Strong_transcription',
#  'Brain_Inferior_Temporal_Lobe_Weak_Repressed_PolyComb',
#  'Brain_Inferior_Temporal_Lobe_Weak_transcription',
#  'Brain_Inferior_Temporal_Lobe_ZNF_genes_and_repeats',
#  'Brain_Mid_Frontal_Lobe_Active_TSS',
#  'Brain_Mid_Frontal_Lobe_Bivalent_Poised_TSS',
#  'Brain_Mid_Frontal_Lobe_Enhancers',
#  'Brain_Mid_Frontal_Lobe_Flanking_Active_TSS',
#  'Brain_Mid_Frontal_Lobe_Genic_enhancers',
#  'Brain_Mid_Frontal_Lobe_Heterochromatin',
#  'Brain_Mid_Frontal_Lobe_Quiescent_Low',
#  'Brain_Mid_Frontal_Lobe_Repressed_PolyComb',
#  'Brain_Mid_Frontal_Lobe_Strong_transcription',
#  'Brain_Mid_Frontal_Lobe_Weak_Repressed_PolyComb',
#  'Brain_Mid_Frontal_Lobe_Weak_transcription',
#  'Brain_Mid_Frontal_Lobe_ZNF_genes_and_repeats',
#  'Brain_Substantia_Nigra_Active_TSS',
#  'Brain_Substantia_Nigra_Bivalent_Enhancer',
#  'Brain_Substantia_Nigra_Enhancers',
#  'Brain_Substantia_Nigra_Flanking_Active_TSS',
#  'Brain_Substantia_Nigra_Genic_enhancers',
#  'Brain_Substantia_Nigra_Heterochromatin',
#  'Brain_Substantia_Nigra_Quiescent_Low',
#  'Brain_Substantia_Nigra_Repressed_PolyComb',
#  'Brain_Substantia_Nigra_Strong_transcription',
#  'Brain_Substantia_Nigra_Weak_Repressed_PolyComb',
#  'Brain_Substantia_Nigra_Weak_transcription',
#  'Brain_Substantia_Nigra_ZNF_genes_and_repeats',
#  'Breast_Myoepithelial_Cells_Active_TSS',
#  'Breast_Myoepithelial_Cells_Bivalent_Enhancer',
#  'Breast_Myoepithelial_Cells_Bivalent_Poised_TSS',
#  'Breast_Myoepithelial_Cells_Enhancers',
#  'Breast_Myoepithelial_Cells_Flanking_Active_TSS',
#  'Breast_Myoepithelial_Cells_Flanking_Bivalent_TSS_Enh',
#  'Breast_Myoepithelial_Cells_Genic_enhancers',
#  'Breast_Myoepithelial_Cells_Heterochromatin',
#  'Breast_Myoepithelial_Cells_Quiescent_Low',
#  'Breast_Myoepithelial_Cells_Repressed_PolyComb',
#  'Breast_Myoepithelial_Cells_Strong_transcription',
#  'Breast_Myoepithelial_Cells_Transcr_at_gene_5_and_3',
#  'Breast_Myoepithelial_Cells_Weak_Repressed_PolyComb',
#  'Breast_Myoepithelial_Cells_Weak_transcription',
#  'Breast_Myoepithelial_Cells_ZNF_genes_and_repeats',
#  'Breast_vHMEC_Active_TSS',
#  'Breast_vHMEC_Bivalent_Enhancer',
#  'Breast_vHMEC_Bivalent_Poised_TSS',
#  'Breast_vHMEC_Enhancers',
#  'Breast_vHMEC_Flanking_Active_TSS',
#  'Breast_vHMEC_Genic_enhancers',
#  'Breast_vHMEC_Heterochromatin',
#  'Breast_vHMEC_Quiescent_Low',
#  'Breast_vHMEC_Repressed_PolyComb',
#  'Breast_vHMEC_Strong_transcription',
#  'Breast_vHMEC_Weak_Repressed_PolyComb',
#  'Breast_vHMEC_Weak_transcription',
#  'Breast_vHMEC_ZNF_genes_and_repeats',
#  'CD14_Primary_Cells_Active_TSS',
#  'CD14_Primary_Cells_Bivalent_Enhancer',
#  'CD14_Primary_Cells_Enhancers',
#  'CD14_Primary_Cells_Flanking_Active_TSS',
#  'CD14_Primary_Cells_Genic_enhancers',
#  'CD14_Primary_Cells_Heterochromatin',
#  'CD14_Primary_Cells_Quiescent_Low',
#  'CD14_Primary_Cells_Repressed_PolyComb',
#  'CD14_Primary_Cells_Strong_transcription',
#  'CD14_Primary_Cells_Weak_Repressed_PolyComb',
#  'CD14_Primary_Cells_Weak_transcription',
#  'CD14_Primary_Cells_ZNF_genes_and_repeats',
#  'CD15_Primary_Cells_Active_TSS',
#  'CD15_Primary_Cells_Bivalent_Enhancer',
#  'CD15_Primary_Cells_Enhancers',
#  'CD15_Primary_Cells_Flanking_Active_TSS',
#  'CD15_Primary_Cells_Flanking_Bivalent_TSS_Enh',
#  'CD15_Primary_Cells_Genic_enhancers',
#  'CD15_Primary_Cells_Heterochromatin',
#  'CD15_Primary_Cells_Quiescent_Low',
#  'CD15_Primary_Cells_Repressed_PolyComb',
#  'CD15_Primary_Cells_Strong_transcription',
#  'CD15_Primary_Cells_Transcr_at_gene_5_and_3',
#  'CD15_Primary_Cells_Weak_Repressed_PolyComb',
#  'CD15_Primary_Cells_Weak_transcription',
#  'CD15_Primary_Cells_ZNF_genes_and_repeats',
#  'CD19_Primary_Cells_Cord_BI_Active_TSS',
#  'CD19_Primary_Cells_Cord_BI_Bivalent_Enhancer',
#  'CD19_Primary_Cells_Cord_BI_Enhancers',
#  'CD19_Primary_Cells_Cord_BI_Flanking_Active_TSS',
#  'CD19_Primary_Cells_Cord_BI_Genic_enhancers',
#  'CD19_Primary_Cells_Cord_BI_Heterochromatin',
#  'CD19_Primary_Cells_Cord_BI_Quiescent_Low',
#  'CD19_Primary_Cells_Cord_BI_Repressed_PolyComb',
#  'CD19_Primary_Cells_Cord_BI_Strong_transcription',
#  'CD19_Primary_Cells_Cord_BI_Weak_Repressed_PolyComb',
#  'CD19_Primary_Cells_Cord_BI_Weak_transcription',
#  'CD19_Primary_Cells_Cord_BI_ZNF_genes_and_repeats',
#  'CD19_Primary_Cells_Peripheral_UW_Active_TSS',
#  'CD19_Primary_Cells_Peripheral_UW_Bivalent_Enhancer',
#  'CD19_Primary_Cells_Peripheral_UW_Enhancers',
#  'CD19_Primary_Cells_Peripheral_UW_Flanking_Active_TSS',
#  'CD19_Primary_Cells_Peripheral_UW_Genic_enhancers',
#  'CD19_Primary_Cells_Peripheral_UW_Heterochromatin',
#  'CD19_Primary_Cells_Peripheral_UW_Quiescent_Low',
#  'CD19_Primary_Cells_Peripheral_UW_Repressed_PolyComb',
#  'CD19_Primary_Cells_Peripheral_UW_Strong_transcription',
#  'CD19_Primary_Cells_Peripheral_UW_Weak_Repressed_PolyComb',
#  'CD19_Primary_Cells_Peripheral_UW_Weak_transcription',
#  'CD19_Primary_Cells_Peripheral_UW_ZNF_genes_and_repeats',
#  'CD34_Cultured_Cells_Active_TSS',
#  'CD34_Cultured_Cells_Bivalent_Enhancer',
#  'CD34_Cultured_Cells_Enhancers',
#  'CD34_Cultured_Cells_Flanking_Active_TSS',
#  'CD34_Cultured_Cells_Flanking_Bivalent_TSS_Enh',
#  'CD34_Cultured_Cells_Genic_enhancers',
#  'CD34_Cultured_Cells_Heterochromatin',
#  'CD34_Cultured_Cells_Quiescent_Low',
#  'CD34_Cultured_Cells_Repressed_PolyComb',
#  'CD34_Cultured_Cells_Strong_transcription',
#  'CD34_Cultured_Cells_Transcr_at_gene_5_and_3',
#  'CD34_Cultured_Cells_Weak_Repressed_PolyComb',
#  'CD34_Cultured_Cells_Weak_transcription',
#  'CD34_Cultured_Cells_ZNF_genes_and_repeats',
#  'CD34_Primary_Cells_Active_TSS',
#  'CD34_Primary_Cells_Bivalent_Enhancer',
#  'CD34_Primary_Cells_Enhancers',
#  'CD34_Primary_Cells_Flanking_Active_TSS',
#  'CD34_Primary_Cells_Genic_enhancers',
#  'CD34_Primary_Cells_Heterochromatin',
#  'CD34_Primary_Cells_Quiescent_Low',
#  'CD34_Primary_Cells_Repressed_PolyComb',
#  'CD34_Primary_Cells_Strong_transcription',
#  'CD34_Primary_Cells_Weak_Repressed_PolyComb',
#  'CD34_Primary_Cells_Weak_transcription',
#  'CD34_Primary_Cells_ZNF_genes_and_repeats',
#  'CD3_Primary_Cells_Cord_BI_Active_TSS',
#  'CD3_Primary_Cells_Cord_BI_Bivalent_Enhancer',
#  'CD3_Primary_Cells_Cord_BI_Bivalent_Poised_TSS',
#  'CD3_Primary_Cells_Cord_BI_Enhancers',
#  'CD3_Primary_Cells_Cord_BI_Flanking_Active_TSS',
#  'CD3_Primary_Cells_Cord_BI_Flanking_Bivalent_TSS_Enh',
#  'CD3_Primary_Cells_Cord_BI_Genic_enhancers',
#  'CD3_Primary_Cells_Cord_BI_Heterochromatin',
#  'CD3_Primary_Cells_Cord_BI_Quiescent_Low',
#  'CD3_Primary_Cells_Cord_BI_Repressed_PolyComb',
#  'CD3_Primary_Cells_Cord_BI_Strong_transcription',
#  'CD3_Primary_Cells_Cord_BI_Weak_Repressed_PolyComb',
#  'CD3_Primary_Cells_Cord_BI_Weak_transcription',
#  'CD3_Primary_Cells_Cord_BI_ZNF_genes_and_repeats',
#  'CD3_Primary_Cells_Peripheral_UW_Active_TSS',
#  'CD3_Primary_Cells_Peripheral_UW_Bivalent_Enhancer',
#  'CD3_Primary_Cells_Peripheral_UW_Bivalent_Poised_TSS',
#  'CD3_Primary_Cells_Peripheral_UW_Enhancers',
#  'CD3_Primary_Cells_Peripheral_UW_Flanking_Active_TSS',
#  'CD3_Primary_Cells_Peripheral_UW_Flanking_Bivalent_TSS_Enh',
#  'CD3_Primary_Cells_Peripheral_UW_Genic_enhancers',
#  'CD3_Primary_Cells_Peripheral_UW_Heterochromatin',
#  'CD3_Primary_Cells_Peripheral_UW_Quiescent_Low',
#  'CD3_Primary_Cells_Peripheral_UW_Repressed_PolyComb',
#  'CD3_Primary_Cells_Peripheral_UW_Strong_transcription',
#  'CD3_Primary_Cells_Peripheral_UW_Transcr_at_gene_5_and_3',
#  'CD3_Primary_Cells_Peripheral_UW_Weak_Repressed_PolyComb',
#  'CD3_Primary_Cells_Peripheral_UW_Weak_transcription',
#  'CD3_Primary_Cells_Peripheral_UW_ZNF_genes_and_repeats',
#  'CD4_Memory_Primary_Cells_Active_TSS',
#  'CD4_Memory_Primary_Cells_Bivalent_Enhancer',
#  'CD4_Memory_Primary_Cells_Enhancers',
#  'CD4_Memory_Primary_Cells_Flanking_Active_TSS',
#  'CD4_Memory_Primary_Cells_Genic_enhancers',
#  'CD4_Memory_Primary_Cells_Heterochromatin',
#  'CD4_Memory_Primary_Cells_Quiescent_Low',
#  'CD4_Memory_Primary_Cells_Repressed_PolyComb',
#  'CD4_Memory_Primary_Cells_Strong_transcription',
#  'CD4_Memory_Primary_Cells_Weak_Repressed_PolyComb',
#  'CD4_Memory_Primary_Cells_Weak_transcription',
#  'CD4_Memory_Primary_Cells_ZNF_genes_and_repeats',
#  'CD4_Naive_Primary_Cells_Active_TSS',
#  'CD4_Naive_Primary_Cells_Bivalent_Enhancer',
#  'CD4_Naive_Primary_Cells_Enhancers',
#  'CD4_Naive_Primary_Cells_Flanking_Active_TSS',
#  'CD4_Naive_Primary_Cells_Genic_enhancers',
#  'CD4_Naive_Primary_Cells_Heterochromatin',
#  'CD4_Naive_Primary_Cells_Quiescent_Low',
#  'CD4_Naive_Primary_Cells_Repressed_PolyComb',
#  'CD4_Naive_Primary_Cells_Strong_transcription',
#  'CD4_Naive_Primary_Cells_Weak_Repressed_PolyComb',
#  'CD4_Naive_Primary_Cells_Weak_transcription',
#  'CD4_Naive_Primary_Cells_ZNF_genes_and_repeats',
#  'CD4pp_CD25__CD45RApp_Naive_Primary_Cells_Active_TSS',
#  'CD4pp_CD25__CD45RApp_Naive_Primary_Cells_Bivalent_Enhancer',
#  'CD4pp_CD25__CD45RApp_Naive_Primary_Cells_Enhancers',
#  'CD4pp_CD25__CD45RApp_Naive_Primary_Cells_Flanking_Active_TSS',
#  'CD4pp_CD25__CD45RApp_Naive_Primary_Cells_Genic_enhancers',
#  'CD4pp_CD25__CD45RApp_Naive_Primary_Cells_Heterochromatin',
#  'CD4pp_CD25__CD45RApp_Naive_Primary_Cells_Quiescent_Low',
#  'CD4pp_CD25__CD45RApp_Naive_Primary_Cells_Repressed_PolyComb',
#  'CD4pp_CD25__CD45RApp_Naive_Primary_Cells_Strong_transcription',
#  'CD4pp_CD25__CD45RApp_Naive_Primary_Cells_Transcr_at_gene_5_and_3',
#  'CD4pp_CD25__CD45RApp_Naive_Primary_Cells_Weak_Repressed_PolyComb',
#  'CD4pp_CD25__CD45RApp_Naive_Primary_Cells_Weak_transcription',
#  'CD4pp_CD25__CD45RApp_Naive_Primary_Cells_ZNF_genes_and_repeats',
#  'CD4pp_CD25__CD45ROpp_Memory_Primary_Cells_Active_TSS',
#  'CD4pp_CD25__CD45ROpp_Memory_Primary_Cells_Bivalent_Enhancer',
#  'CD4pp_CD25__CD45ROpp_Memory_Primary_Cells_Enhancers',
#  'CD4pp_CD25__CD45ROpp_Memory_Primary_Cells_Flanking_Active_TSS',
#  'CD4pp_CD25__CD45ROpp_Memory_Primary_Cells_Genic_enhancers',
#  'CD4pp_CD25__CD45ROpp_Memory_Primary_Cells_Heterochromatin',
#  'CD4pp_CD25__CD45ROpp_Memory_Primary_Cells_Quiescent_Low',
#  'CD4pp_CD25__CD45ROpp_Memory_Primary_Cells_Repressed_PolyComb',
#  'CD4pp_CD25__CD45ROpp_Memory_Primary_Cells_Strong_transcription',
#  'CD4pp_CD25__CD45ROpp_Memory_Primary_Cells_Weak_Repressed_PolyComb',
#  'CD4pp_CD25__CD45ROpp_Memory_Primary_Cells_Weak_transcription',
#  'CD4pp_CD25__CD45ROpp_Memory_Primary_Cells_ZNF_genes_and_repeats',
#  'CD4pp_CD25__IL17__PMA_Ionomycin_stimulated_MACS_purified_Th_Primary_Cells_Active_TSS',
#  'CD4pp_CD25__IL17__PMA_Ionomycin_stimulated_MACS_purified_Th_Primary_Cells_Bivalent_Enhancer',
#  'CD4pp_CD25__IL17__PMA_Ionomycin_stimulated_MACS_purified_Th_Primary_Cells_Enhancers',
#  'CD4pp_CD25__IL17__PMA_Ionomycin_stimulated_MACS_purified_Th_Primary_Cells_Flanking_Active_TSS',
#  'CD4pp_CD25__IL17__PMA_Ionomycin_stimulated_MACS_purified_Th_Primary_Cells_Flanking_Bivalent_TSS_Enh',
#  'CD4pp_CD25__IL17__PMA_Ionomycin_stimulated_MACS_purified_Th_Primary_Cells_Genic_enhancers',
#  'CD4pp_CD25__IL17__PMA_Ionomycin_stimulated_MACS_purified_Th_Primary_Cells_Heterochromatin',
#  'CD4pp_CD25__IL17__PMA_Ionomycin_stimulated_MACS_purified_Th_Primary_Cells_Quiescent_Low',
#  'CD4pp_CD25__IL17__PMA_Ionomycin_stimulated_MACS_purified_Th_Primary_Cells_Repressed_PolyComb',
#  'CD4pp_CD25__IL17__PMA_Ionomycin_stimulated_MACS_purified_Th_Primary_Cells_Strong_transcription',
#  'CD4pp_CD25__IL17__PMA_Ionomycin_stimulated_MACS_purified_Th_Primary_Cells_Transcr_at_gene_5_and_3',
#  'CD4pp_CD25__IL17__PMA_Ionomycin_stimulated_MACS_purified_Th_Primary_Cells_Weak_Repressed_PolyComb',
#  'CD4pp_CD25__IL17__PMA_Ionomycin_stimulated_MACS_purified_Th_Primary_Cells_Weak_transcription',
#  'CD4pp_CD25__IL17__PMA_Ionomycin_stimulated_MACS_purified_Th_Primary_Cells_ZNF_genes_and_repeats',
#  'CD4pp_CD25__IL17pp_PMA_Ionomcyin_stimulated_Th17_Primary_Cells_Active_TSS',
#  'CD4pp_CD25__IL17pp_PMA_Ionomcyin_stimulated_Th17_Primary_Cells_Bivalent_Enhancer',
#  'CD4pp_CD25__IL17pp_PMA_Ionomcyin_stimulated_Th17_Primary_Cells_Enhancers',
#  'CD4pp_CD25__IL17pp_PMA_Ionomcyin_stimulated_Th17_Primary_Cells_Flanking_Active_TSS',
#  'CD4pp_CD25__IL17pp_PMA_Ionomcyin_stimulated_Th17_Primary_Cells_Genic_enhancers',
#  'CD4pp_CD25__IL17pp_PMA_Ionomcyin_stimulated_Th17_Primary_Cells_Heterochromatin',
#  'CD4pp_CD25__IL17pp_PMA_Ionomcyin_stimulated_Th17_Primary_Cells_Quiescent_Low',
#  'CD4pp_CD25__IL17pp_PMA_Ionomcyin_stimulated_Th17_Primary_Cells_Repressed_PolyComb',
#  'CD4pp_CD25__IL17pp_PMA_Ionomcyin_stimulated_Th17_Primary_Cells_Strong_transcription',
#  'CD4pp_CD25__IL17pp_PMA_Ionomcyin_stimulated_Th17_Primary_Cells_Transcr_at_gene_5_and_3',
#  'CD4pp_CD25__IL17pp_PMA_Ionomcyin_stimulated_Th17_Primary_Cells_Weak_Repressed_PolyComb',
#  'CD4pp_CD25__IL17pp_PMA_Ionomcyin_stimulated_Th17_Primary_Cells_Weak_transcription',
#  'CD4pp_CD25__IL17pp_PMA_Ionomcyin_stimulated_Th17_Primary_Cells_ZNF_genes_and_repeats',
#  'CD4pp_CD25int_CD127pp_Tmem_Primary_Cells_Active_TSS',
#  'CD4pp_CD25int_CD127pp_Tmem_Primary_Cells_Bivalent_Enhancer',
#  'CD4pp_CD25int_CD127pp_Tmem_Primary_Cells_Enhancers',
#  'CD4pp_CD25int_CD127pp_Tmem_Primary_Cells_Flanking_Active_TSS',
#  'CD4pp_CD25int_CD127pp_Tmem_Primary_Cells_Genic_enhancers',
#  'CD4pp_CD25int_CD127pp_Tmem_Primary_Cells_Heterochromatin',
#  'CD4pp_CD25int_CD127pp_Tmem_Primary_Cells_Quiescent_Low',
#  'CD4pp_CD25int_CD127pp_Tmem_Primary_Cells_Repressed_PolyComb',
#  'CD4pp_CD25int_CD127pp_Tmem_Primary_Cells_Strong_transcription',
#  'CD4pp_CD25int_CD127pp_Tmem_Primary_Cells_Weak_Repressed_PolyComb',
#  'CD4pp_CD25int_CD127pp_Tmem_Primary_Cells_Weak_transcription',
#  'CD4pp_CD25int_CD127pp_Tmem_Primary_Cells_ZNF_genes_and_repeats',
#  'CD4pp_CD25pp_CD127__Treg_Primary_Cells_Active_TSS',
#  'CD4pp_CD25pp_CD127__Treg_Primary_Cells_Bivalent_Enhancer',
#  'CD4pp_CD25pp_CD127__Treg_Primary_Cells_Bivalent_Poised_TSS',
#  'CD4pp_CD25pp_CD127__Treg_Primary_Cells_Enhancers',
#  'CD4pp_CD25pp_CD127__Treg_Primary_Cells_Flanking_Active_TSS',
#  'CD4pp_CD25pp_CD127__Treg_Primary_Cells_Flanking_Bivalent_TSS_Enh',
#  'CD4pp_CD25pp_CD127__Treg_Primary_Cells_Genic_enhancers',
#  'CD4pp_CD25pp_CD127__Treg_Primary_Cells_Heterochromatin',
#  'CD4pp_CD25pp_CD127__Treg_Primary_Cells_Quiescent_Low',
#  'CD4pp_CD25pp_CD127__Treg_Primary_Cells_Repressed_PolyComb',
#  'CD4pp_CD25pp_CD127__Treg_Primary_Cells_Strong_transcription',
#  'CD4pp_CD25pp_CD127__Treg_Primary_Cells_Transcr_at_gene_5_and_3',
#  'CD4pp_CD25pp_CD127__Treg_Primary_Cells_Weak_Repressed_PolyComb',
#  'CD4pp_CD25pp_CD127__Treg_Primary_Cells_Weak_transcription',
#  'CD4pp_CD25pp_CD127__Treg_Primary_Cells_ZNF_genes_and_repeats',
#  'CD4pp_CD25__Th_Primary_Cells_Active_TSS',
#  'CD4pp_CD25__Th_Primary_Cells_Bivalent_Enhancer',
#  'CD4pp_CD25__Th_Primary_Cells_Enhancers',
#  'CD4pp_CD25__Th_Primary_Cells_Flanking_Active_TSS',
#  'CD4pp_CD25__Th_Primary_Cells_Flanking_Bivalent_TSS_Enh',
#  'CD4pp_CD25__Th_Primary_Cells_Genic_enhancers',
#  'CD4pp_CD25__Th_Primary_Cells_Heterochromatin',
#  'CD4pp_CD25__Th_Primary_Cells_Quiescent_Low',
#  'CD4pp_CD25__Th_Primary_Cells_Repressed_PolyComb',
#  'CD4pp_CD25__Th_Primary_Cells_Strong_transcription',
#  'CD4pp_CD25__Th_Primary_Cells_Weak_Repressed_PolyComb',
#  'CD4pp_CD25__Th_Primary_Cells_Weak_transcription',
#  'CD4pp_CD25__Th_Primary_Cells_ZNF_genes_and_repeats',
#  'CD56_Primary_Cells_Active_TSS',
#  'CD56_Primary_Cells_Bivalent_Enhancer',
#  'CD56_Primary_Cells_Enhancers',
#  'CD56_Primary_Cells_Flanking_Active_TSS',
#  'CD56_Primary_Cells_Genic_enhancers',
#  'CD56_Primary_Cells_Heterochromatin',
#  'CD56_Primary_Cells_Quiescent_Low',
#  'CD56_Primary_Cells_Repressed_PolyComb',
#  'CD56_Primary_Cells_Strong_transcription',
#  'CD56_Primary_Cells_Weak_Repressed_PolyComb',
#  'CD56_Primary_Cells_Weak_transcription',
#  'CD56_Primary_Cells_ZNF_genes_and_repeats',
#  'CD8_Memory_Primary_Cells_Active_TSS',
#  'CD8_Memory_Primary_Cells_Bivalent_Enhancer',
#  'CD8_Memory_Primary_Cells_Enhancers',
#  'CD8_Memory_Primary_Cells_Flanking_Active_TSS',
#  'CD8_Memory_Primary_Cells_Genic_enhancers',
#  'CD8_Memory_Primary_Cells_Heterochromatin',
#  'CD8_Memory_Primary_Cells_Quiescent_Low',
#  'CD8_Memory_Primary_Cells_Repressed_PolyComb',
#  'CD8_Memory_Primary_Cells_Strong_transcription',
#  'CD8_Memory_Primary_Cells_Weak_Repressed_PolyComb',
#  'CD8_Memory_Primary_Cells_Weak_transcription',
#  'CD8_Memory_Primary_Cells_ZNF_genes_and_repeats',
#  'CD8_Naive_Primary_Cells_Active_TSS',
#  'CD8_Naive_Primary_Cells_Bivalent_Enhancer',
#  'CD8_Naive_Primary_Cells_Enhancers',
#  'CD8_Naive_Primary_Cells_Flanking_Active_TSS',
#  'CD8_Naive_Primary_Cells_Genic_enhancers',
#  'CD8_Naive_Primary_Cells_Heterochromatin',
#  'CD8_Naive_Primary_Cells_Quiescent_Low',
#  'CD8_Naive_Primary_Cells_Repressed_PolyComb',
#  'CD8_Naive_Primary_Cells_Strong_transcription',
#  'CD8_Naive_Primary_Cells_Weak_Repressed_PolyComb',
#  'CD8_Naive_Primary_Cells_Weak_transcription',
#  'CD8_Naive_Primary_Cells_ZNF_genes_and_repeats',
#  'Chondrocytes_from_Bone_Marrow_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Active_TSS',
#  'Chondrocytes_from_Bone_Marrow_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Bivalent_Enhancer',
#  'Chondrocytes_from_Bone_Marrow_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Bivalent_Poised_TSS',
#  'Chondrocytes_from_Bone_Marrow_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Enhancers',
#  'Chondrocytes_from_Bone_Marrow_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Flanking_Active_TSS',
#  'Chondrocytes_from_Bone_Marrow_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Genic_enhancers',
#  'Chondrocytes_from_Bone_Marrow_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Heterochromatin',
#  'Chondrocytes_from_Bone_Marrow_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Quiescent_Low',
#  'Chondrocytes_from_Bone_Marrow_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Repressed_PolyComb',
#  'Chondrocytes_from_Bone_Marrow_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Strong_transcription',
#  'Chondrocytes_from_Bone_Marrow_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Transcr_at_gene_5_and_3',
#  'Chondrocytes_from_Bone_Marrow_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Weak_Repressed_PolyComb',
#  'Chondrocytes_from_Bone_Marrow_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_Weak_transcription',
#  'Chondrocytes_from_Bone_Marrow_Derived_Mesenchymal_Stem_Cell_Cultured_Cells_ZNF_genes_and_repeats',
#  'Colonic_Mucosa_Active_TSS',
#  'Colonic_Mucosa_Bivalent_Enhancer',
#  'Colonic_Mucosa_Bivalent_Poised_TSS',
#  'Colonic_Mucosa_Enhancers',
#  'Colonic_Mucosa_Flanking_Active_TSS',
#  'Colonic_Mucosa_Flanking_Bivalent_TSS_Enh',
#  'Colonic_Mucosa_Genic_enhancers',
#  'Colonic_Mucosa_Heterochromatin',
#  'Colonic_Mucosa_Quiescent_Low',
#  'Colonic_Mucosa_Repressed_PolyComb',
#  'Colonic_Mucosa_Strong_transcription',
#  'Colonic_Mucosa_Weak_Repressed_PolyComb',
#  'Colonic_Mucosa_Weak_transcription',
#  'Colonic_Mucosa_ZNF_genes_and_repeats',
#  'Colon_Smooth_Muscle_Active_TSS',
#  'Colon_Smooth_Muscle_Bivalent_Enhancer',
#  'Colon_Smooth_Muscle_Bivalent_Poised_TSS',
#  'Colon_Smooth_Muscle_Enhancers',
#  'Colon_Smooth_Muscle_Flanking_Active_TSS',
#  'Colon_Smooth_Muscle_Genic_enhancers',
#  'Colon_Smooth_Muscle_Heterochromatin',
#  'Colon_Smooth_Muscle_Quiescent_Low',
#  'Colon_Smooth_Muscle_Repressed_PolyComb',
#  'Colon_Smooth_Muscle_Strong_transcription',
#  'Colon_Smooth_Muscle_Weak_Repressed_PolyComb',
#  'Colon_Smooth_Muscle_Weak_transcription',
#  'Colon_Smooth_Muscle_ZNF_genes_and_repeats',
#  'Dnd41_TCell_Leukemia_Active_TSS',
#  'Dnd41_TCell_Leukemia_Enhancers',
#  'Dnd41_TCell_Leukemia_Flanking_Active_TSS',
#  'Dnd41_TCell_Leukemia_Genic_enhancers',
#  'Dnd41_TCell_Leukemia_Heterochromatin',
#  'Dnd41_TCell_Leukemia_Quiescent_Low',
#  'Dnd41_TCell_Leukemia_Repressed_PolyComb',
#  'Dnd41_TCell_Leukemia_Strong_transcription',
#  'Dnd41_TCell_Leukemia_Transcr_at_gene_5_and_3',
#  'Dnd41_TCell_Leukemia_Weak_Repressed_PolyComb',
#  'Dnd41_TCell_Leukemia_Weak_transcription',
#  'Dnd41_TCell_Leukemia_ZNF_genes_and_repeats',
#  'Duodenum_Mucosa_Active_TSS',
#  'Duodenum_Mucosa_Bivalent_Enhancer',
#  'Duodenum_Mucosa_Bivalent_Poised_TSS',
#  'Duodenum_Mucosa_Enhancers',
#  'Duodenum_Mucosa_Flanking_Active_TSS',
#  'Duodenum_Mucosa_Flanking_Bivalent_TSS_Enh',
#  'Duodenum_Mucosa_Genic_enhancers',
#  'Duodenum_Mucosa_Heterochromatin',
#  'Duodenum_Mucosa_Quiescent_Low',
#  'Duodenum_Mucosa_Repressed_PolyComb',
#  'Duodenum_Mucosa_Strong_transcription',
#  'Duodenum_Mucosa_Transcr_at_gene_5_and_3',
#  'Duodenum_Mucosa_Weak_Repressed_PolyComb',
#  'Duodenum_Mucosa_Weak_transcription',
#  'Duodenum_Mucosa_ZNF_genes_and_repeats',
#  'Duodenum_Smooth_Muscle_Active_TSS',
#  'Duodenum_Smooth_Muscle_Bivalent_Enhancer',
#  'Duodenum_Smooth_Muscle_Bivalent_Poised_TSS',
#  'Duodenum_Smooth_Muscle_Enhancers',
#  'Duodenum_Smooth_Muscle_Flanking_Active_TSS',
#  'Duodenum_Smooth_Muscle_Flanking_Bivalent_TSS_Enh',
#  'Duodenum_Smooth_Muscle_Genic_enhancers',
#  'Duodenum_Smooth_Muscle_Heterochromatin',
#  'Duodenum_Smooth_Muscle_Quiescent_Low',
#  'Duodenum_Smooth_Muscle_Repressed_PolyComb',
#  'Duodenum_Smooth_Muscle_Strong_transcription',
#  'Duodenum_Smooth_Muscle_Weak_Repressed_PolyComb',
#  'Duodenum_Smooth_Muscle_Weak_transcription',
#  'Duodenum_Smooth_Muscle_ZNF_genes_and_repeats',
#  'ES_I3_Cell_Line_Active_TSS',
#  'ES_I3_Cell_Line_Bivalent_Enhancer',
#  'ES_I3_Cell_Line_Bivalent_Poised_TSS',
#  'ES_I3_Cell_Line_Enhancers',
#  'ES_I3_Cell_Line_Flanking_Active_TSS',
#  'ES_I3_Cell_Line_Flanking_Bivalent_TSS_Enh',
#  'ES_I3_Cell_Line_Heterochromatin',
#  'ES_I3_Cell_Line_Quiescent_Low',
#  'ES_I3_Cell_Line_Repressed_PolyComb',
#  'ES_I3_Cell_Line_Strong_transcription',
#  'ES_I3_Cell_Line_Weak_Repressed_PolyComb',
#  'ES_I3_Cell_Line_Weak_transcription',
#  'ES_I3_Cell_Line_ZNF_genes_and_repeats',
#  'Esophagus_Active_TSS',
#  'Esophagus_Bivalent_Enhancer',
#  'Esophagus_Enhancers',
#  'Esophagus_Flanking_Active_TSS',
#  'Esophagus_Genic_enhancers',
#  'Esophagus_Heterochromatin',
#  'Esophagus_Quiescent_Low',
#  'Esophagus_Repressed_PolyComb',
#  'Esophagus_Strong_transcription',
#  'Esophagus_Weak_Repressed_PolyComb',
#  'Esophagus_Weak_transcription',
#  'Esophagus_ZNF_genes_and_repeats',
#  'ES_WA7_Cell_Line_Active_TSS',
#  'ES_WA7_Cell_Line_Bivalent_Enhancer',
#  'ES_WA7_Cell_Line_Bivalent_Poised_TSS',
#  'ES_WA7_Cell_Line_Enhancers',
#  'ES_WA7_Cell_Line_Heterochromatin',
#  'ES_WA7_Cell_Line_Quiescent_Low',
#  'ES_WA7_Cell_Line_Repressed_PolyComb',
#  'ES_WA7_Cell_Line_Weak_Repressed_PolyComb',
#  'ES_WA7_Cell_Line_Weak_transcription',
#  'Fetal_Adrenal_Gland_Active_TSS',
#  'Fetal_Adrenal_Gland_Bivalent_Enhancer',
#  'Fetal_Adrenal_Gland_Bivalent_Poised_TSS',
#  'Fetal_Adrenal_Gland_Enhancers',
#  'Fetal_Adrenal_Gland_Flanking_Active_TSS',
#  'Fetal_Adrenal_Gland_Flanking_Bivalent_TSS_Enh',
#  'Fetal_Adrenal_Gland_Genic_enhancers',
#  'Fetal_Adrenal_Gland_Heterochromatin',
#  'Fetal_Adrenal_Gland_Quiescent_Low',
#  'Fetal_Adrenal_Gland_Repressed_PolyComb',
#  'Fetal_Adrenal_Gland_Strong_transcription',
#  'Fetal_Adrenal_Gland_Weak_Repressed_PolyComb',
#  'Fetal_Adrenal_Gland_Weak_transcription',
#  'Fetal_Adrenal_Gland_ZNF_genes_and_repeats',
#  'Fetal_Brain_Female_Active_TSS',
#  'Fetal_Brain_Female_Bivalent_Poised_TSS',
#  'Fetal_Brain_Female_Enhancers',
#  'Fetal_Brain_Female_Flanking_Active_TSS',
#  'Fetal_Brain_Female_Genic_enhancers',
#  'Fetal_Brain_Female_Heterochromatin',
#  'Fetal_Brain_Female_Quiescent_Low',
#  'Fetal_Brain_Female_Repressed_PolyComb',
#  'Fetal_Brain_Female_Strong_transcription',
#  'Fetal_Brain_Female_Weak_Repressed_PolyComb',
#  'Fetal_Brain_Female_Weak_transcription',
#  'Fetal_Brain_Female_ZNF_genes_and_repeats',
#  'Fetal_Brain_Male_Active_TSS',
#  'Fetal_Brain_Male_Bivalent_Enhancer',
#  'Fetal_Brain_Male_Enhancers',
#  'Fetal_Brain_Male_Flanking_Active_TSS',
#  'Fetal_Brain_Male_Flanking_Bivalent_TSS_Enh',
#  'Fetal_Brain_Male_Genic_enhancers',
#  'Fetal_Brain_Male_Heterochromatin',
#  'Fetal_Brain_Male_Quiescent_Low',
#  'Fetal_Brain_Male_Repressed_PolyComb',
#  'Fetal_Brain_Male_Strong_transcription',
#  'Fetal_Brain_Male_Weak_Repressed_PolyComb',
#  'Fetal_Brain_Male_Weak_transcription',
#  'Fetal_Brain_Male_ZNF_genes_and_repeats',
#  'Fetal_Heart_Active_TSS',
#  'Fetal_Heart_Bivalent_Enhancer',
#  'Fetal_Heart_Enhancers',
#  'Fetal_Heart_Flanking_Active_TSS',
#  'Fetal_Heart_Genic_enhancers',
#  'Fetal_Heart_Heterochromatin',
#  'Fetal_Heart_Quiescent_Low',
#  'Fetal_Heart_Repressed_PolyComb',
#  'Fetal_Heart_Strong_transcription',
#  'Fetal_Heart_Weak_Repressed_PolyComb',
#  'Fetal_Heart_Weak_transcription',
#  'Fetal_Heart_ZNF_genes_and_repeats',
#  'Fetal_Intestine_Large_Active_TSS',
#  'Fetal_Intestine_Large_Bivalent_Enhancer',
#  'Fetal_Intestine_Large_Bivalent_Poised_TSS',
#  'Fetal_Intestine_Large_Enhancers',
#  'Fetal_Intestine_Large_Flanking_Active_TSS',
#  'Fetal_Intestine_Large_Flanking_Bivalent_TSS_Enh',
#  'Fetal_Intestine_Large_Genic_enhancers',
#  'Fetal_Intestine_Large_Heterochromatin',
#  'Fetal_Intestine_Large_Quiescent_Low',
#  'Fetal_Intestine_Large_Repressed_PolyComb',
#  'Fetal_Intestine_Large_Strong_transcription',
#  'Fetal_Intestine_Large_Weak_Repressed_PolyComb',
#  'Fetal_Intestine_Large_Weak_transcription',
#  'Fetal_Intestine_Large_ZNF_genes_and_repeats',
#  'Fetal_Intestine_Small_Active_TSS',
#  'Fetal_Intestine_Small_Bivalent_Enhancer',
#  'Fetal_Intestine_Small_Bivalent_Poised_TSS',
#  'Fetal_Intestine_Small_Enhancers',
#  'Fetal_Intestine_Small_Flanking_Active_TSS',
#  'Fetal_Intestine_Small_Flanking_Bivalent_TSS_Enh',
#  'Fetal_Intestine_Small_Genic_enhancers',
#  'Fetal_Intestine_Small_Heterochromatin',
#  'Fetal_Intestine_Small_Quiescent_Low',
#  'Fetal_Intestine_Small_Repressed_PolyComb',
#  'Fetal_Intestine_Small_Strong_transcription',
#  'Fetal_Intestine_Small_Transcr_at_gene_5_and_3',
#  'Fetal_Intestine_Small_Weak_Repressed_PolyComb',
#  'Fetal_Intestine_Small_Weak_transcription',
#  'Fetal_Intestine_Small_ZNF_genes_and_repeats',
#  'Fetal_Kidney_Active_TSS',
#  'Fetal_Kidney_Bivalent_Enhancer',
#  'Fetal_Kidney_Bivalent_Poised_TSS',
#  'Fetal_Kidney_Enhancers',
#  'Fetal_Kidney_Flanking_Active_TSS',
#  'Fetal_Kidney_Flanking_Bivalent_TSS_Enh',
#  'Fetal_Kidney_Heterochromatin',
#  'Fetal_Kidney_Quiescent_Low',
#  'Fetal_Kidney_Repressed_PolyComb',
#  'Fetal_Kidney_Strong_transcription',
#  'Fetal_Kidney_Weak_Repressed_PolyComb',
#  'Fetal_Kidney_Weak_transcription',
#  'Fetal_Kidney_ZNF_genes_and_repeats',
#  'Fetal_Lung_Active_TSS',
#  'Fetal_Lung_Bivalent_Enhancer',
#  'Fetal_Lung_Bivalent_Poised_TSS',
#  'Fetal_Lung_Enhancers',
#  'Fetal_Lung_Flanking_Active_TSS',
#  'Fetal_Lung_Flanking_Bivalent_TSS_Enh',
#  'Fetal_Lung_Genic_enhancers',
#  'Fetal_Lung_Heterochromatin',
#  'Fetal_Lung_Quiescent_Low',
#  'Fetal_Lung_Repressed_PolyComb',
#  'Fetal_Lung_Strong_transcription',
#  'Fetal_Lung_Weak_Repressed_PolyComb',
#  'Fetal_Lung_Weak_transcription',
#  'Fetal_Lung_ZNF_genes_and_repeats',
#  'Fetal_Muscle_Leg_Active_TSS',
#  'Fetal_Muscle_Leg_Bivalent_Enhancer',
#  'Fetal_Muscle_Leg_Bivalent_Poised_TSS',
#  'Fetal_Muscle_Leg_Enhancers',
#  'Fetal_Muscle_Leg_Flanking_Active_TSS',
#  'Fetal_Muscle_Leg_Flanking_Bivalent_TSS_Enh',
#  'Fetal_Muscle_Leg_Genic_enhancers',
#  'Fetal_Muscle_Leg_Heterochromatin',
#  'Fetal_Muscle_Leg_Quiescent_Low',
#  'Fetal_Muscle_Leg_Repressed_PolyComb',
#  'Fetal_Muscle_Leg_Strong_transcription',
#  'Fetal_Muscle_Leg_Weak_Repressed_PolyComb',
#  'Fetal_Muscle_Leg_Weak_transcription',
#  'Fetal_Muscle_Leg_ZNF_genes_and_repeats',
#  'Fetal_Muscle_Trunk_Active_TSS',
#  'Fetal_Muscle_Trunk_Bivalent_Enhancer',
#  'Fetal_Muscle_Trunk_Bivalent_Poised_TSS',
#  'Fetal_Muscle_Trunk_Enhancers',
#  'Fetal_Muscle_Trunk_Flanking_Active_TSS',
#  'Fetal_Muscle_Trunk_Flanking_Bivalent_TSS_Enh',
#  'Fetal_Muscle_Trunk_Genic_enhancers',
#  'Fetal_Muscle_Trunk_Heterochromatin',
#  'Fetal_Muscle_Trunk_Quiescent_Low',
#  'Fetal_Muscle_Trunk_Repressed_PolyComb',
#  'Fetal_Muscle_Trunk_Strong_transcription',
#  'Fetal_Muscle_Trunk_Weak_Repressed_PolyComb',
#  'Fetal_Muscle_Trunk_Weak_transcription',
#  'Fetal_Muscle_Trunk_ZNF_genes_and_repeats',
#  'Fetal_Placenta_Active_TSS',
#  'Fetal_Placenta_Bivalent_Enhancer',
#  'Fetal_Placenta_Enhancers',
#  'Fetal_Placenta_Flanking_Active_TSS',
#  'Fetal_Placenta_Genic_enhancers',
#  'Fetal_Placenta_Heterochromatin',
#  'Fetal_Placenta_Quiescent_Low',
#  'Fetal_Placenta_Repressed_PolyComb',
#  'Fetal_Placenta_Strong_transcription',
#  'Fetal_Placenta_Weak_Repressed_PolyComb',
#  'Fetal_Placenta_Weak_transcription',
#  'Fetal_Placenta_ZNF_genes_and_repeats',
#  'Fetal_Stomach_Active_TSS',
#  'Fetal_Stomach_Bivalent_Enhancer',
#  'Fetal_Stomach_Bivalent_Poised_TSS',
#  'Fetal_Stomach_Enhancers',
#  'Fetal_Stomach_Flanking_Active_TSS',
#  'Fetal_Stomach_Flanking_Bivalent_TSS_Enh',
#  'Fetal_Stomach_Genic_enhancers',
#  'Fetal_Stomach_Heterochromatin',
#  'Fetal_Stomach_Quiescent_Low',
#  'Fetal_Stomach_Repressed_PolyComb',
#  'Fetal_Stomach_Strong_transcription',
#  'Fetal_Stomach_Transcr_at_gene_5_and_3',
#  'Fetal_Stomach_Weak_Repressed_PolyComb',
#  'Fetal_Stomach_Weak_transcription',
#  'Fetal_Stomach_ZNF_genes_and_repeats',
#  'Fetal_Thymus_Active_TSS',
#  'Fetal_Thymus_Bivalent_Enhancer',
#  'Fetal_Thymus_Bivalent_Poised_TSS',
#  'Fetal_Thymus_Enhancers',
#  'Fetal_Thymus_Flanking_Active_TSS',
#  'Fetal_Thymus_Flanking_Bivalent_TSS_Enh',
#  'Fetal_Thymus_Genic_enhancers',
#  'Fetal_Thymus_Heterochromatin',
#  'Fetal_Thymus_Quiescent_Low',
#  'Fetal_Thymus_Repressed_PolyComb',
#  'Fetal_Thymus_Strong_transcription',
#  'Fetal_Thymus_Transcr_at_gene_5_and_3',
#  'Fetal_Thymus_Weak_Repressed_PolyComb',
#  'Fetal_Thymus_Weak_transcription',
#  'Fetal_Thymus_ZNF_genes_and_repeats',
#  'Gastric_Active_TSS',
#  'Gastric_Enhancers',
#  'Gastric_Flanking_Active_TSS',
#  'Gastric_Genic_enhancers',
#  'Gastric_Heterochromatin',
#  'Gastric_Quiescent_Low',
#  'Gastric_Strong_transcription',
#  'Gastric_Weak_Repressed_PolyComb',
#  'Gastric_Weak_transcription',
#  'Gastric_ZNF_genes_and_repeats',
#  'GM12878_Lymphoblastoid_Active_TSS',
#  'GM12878_Lymphoblastoid_Enhancers',
#  'GM12878_Lymphoblastoid_Flanking_Active_TSS',
#  'GM12878_Lymphoblastoid_Genic_enhancers',
#  'GM12878_Lymphoblastoid_Heterochromatin',
#  'GM12878_Lymphoblastoid_Quiescent_Low',
#  'GM12878_Lymphoblastoid_Repressed_PolyComb',
#  'GM12878_Lymphoblastoid_Strong_transcription',
#  'GM12878_Lymphoblastoid_Transcr_at_gene_5_and_3',
#  'GM12878_Lymphoblastoid_Weak_Repressed_PolyComb',
#  'GM12878_Lymphoblastoid_Weak_transcription',
#  'GM12878_Lymphoblastoid_ZNF_genes_and_repeats',
#  'H1_BMP4_Derived_Mesendoderm_Cultured_Cells_Active_TSS',
#  'H1_BMP4_Derived_Mesendoderm_Cultured_Cells_Bivalent_Poised_TSS',
#  'H1_BMP4_Derived_Mesendoderm_Cultured_Cells_Enhancers',
#  'H1_BMP4_Derived_Mesendoderm_Cultured_Cells_Heterochromatin',
#  'H1_BMP4_Derived_Mesendoderm_Cultured_Cells_Quiescent_Low',
#  'H1_BMP4_Derived_Mesendoderm_Cultured_Cells_Repressed_PolyComb',
#  'H1_BMP4_Derived_Mesendoderm_Cultured_Cells_Weak_Repressed_PolyComb',
#  'H1_BMP4_Derived_Mesendoderm_Cultured_Cells_Weak_transcription',
#  'H1_BMP4_Derived_Trophoblast_Cultured_Cells_Active_TSS',
#  'H1_BMP4_Derived_Trophoblast_Cultured_Cells_Bivalent_Enhancer',
#  'H1_BMP4_Derived_Trophoblast_Cultured_Cells_Enhancers',
#  'H1_BMP4_Derived_Trophoblast_Cultured_Cells_Flanking_Active_TSS',
#  'H1_BMP4_Derived_Trophoblast_Cultured_Cells_Flanking_Bivalent_TSS_Enh',
#  'H1_BMP4_Derived_Trophoblast_Cultured_Cells_Genic_enhancers',
#  'H1_BMP4_Derived_Trophoblast_Cultured_Cells_Heterochromatin',
#  'H1_BMP4_Derived_Trophoblast_Cultured_Cells_Quiescent_Low',
#  'H1_BMP4_Derived_Trophoblast_Cultured_Cells_Repressed_PolyComb',
#  'H1_BMP4_Derived_Trophoblast_Cultured_Cells_Strong_transcription',
#  'H1_BMP4_Derived_Trophoblast_Cultured_Cells_Weak_Repressed_PolyComb',
#  'H1_BMP4_Derived_Trophoblast_Cultured_Cells_Weak_transcription',
#  'H1_BMP4_Derived_Trophoblast_Cultured_Cells_ZNF_genes_and_repeats',
#  'H1_Cell_Line_Active_TSS',
#  'H1_Cell_Line_Bivalent_Enhancer',
#  'H1_Cell_Line_Bivalent_Poised_TSS',
#  'H1_Cell_Line_Enhancers',
#  'H1_Cell_Line_Flanking_Active_TSS',
#  'H1_Cell_Line_Flanking_Bivalent_TSS_Enh',
#  'H1_Cell_Line_Genic_enhancers',
#  'H1_Cell_Line_Heterochromatin',
#  'H1_Cell_Line_Quiescent_Low',
#  'H1_Cell_Line_Repressed_PolyComb',
#  'H1_Cell_Line_Strong_transcription',
#  'H1_Cell_Line_Weak_Repressed_PolyComb',
#  'H1_Cell_Line_Weak_transcription',
#  'H1_Cell_Line_ZNF_genes_and_repeats',
#  'H1_Derived_Mesenchymal_Stem_Cells_Active_TSS',
#  'H1_Derived_Mesenchymal_Stem_Cells_Bivalent_Enhancer',
#  'H1_Derived_Mesenchymal_Stem_Cells_Enhancers',
#  'H1_Derived_Mesenchymal_Stem_Cells_Flanking_Active_TSS',
#  'H1_Derived_Mesenchymal_Stem_Cells_Flanking_Bivalent_TSS_Enh',
#  'H1_Derived_Mesenchymal_Stem_Cells_Genic_enhancers',
#  'H1_Derived_Mesenchymal_Stem_Cells_Heterochromatin',
#  'H1_Derived_Mesenchymal_Stem_Cells_Quiescent_Low',
#  'H1_Derived_Mesenchymal_Stem_Cells_Repressed_PolyComb',
#  'H1_Derived_Mesenchymal_Stem_Cells_Strong_transcription',
#  'H1_Derived_Mesenchymal_Stem_Cells_Transcr_at_gene_5_and_3',
#  'H1_Derived_Mesenchymal_Stem_Cells_Weak_Repressed_PolyComb',
#  'H1_Derived_Mesenchymal_Stem_Cells_Weak_transcription',
#  'H1_Derived_Mesenchymal_Stem_Cells_ZNF_genes_and_repeats',
#  'H1_Derived_Neuronal_Progenitor_Cultured_Cells_Active_TSS',
#  'H1_Derived_Neuronal_Progenitor_Cultured_Cells_Bivalent_Poised_TSS',
#  'H1_Derived_Neuronal_Progenitor_Cultured_Cells_Enhancers',
#  'H1_Derived_Neuronal_Progenitor_Cultured_Cells_Flanking_Active_TSS',
#  'H1_Derived_Neuronal_Progenitor_Cultured_Cells_Heterochromatin',
#  'H1_Derived_Neuronal_Progenitor_Cultured_Cells_Quiescent_Low',
#  'H1_Derived_Neuronal_Progenitor_Cultured_Cells_Repressed_PolyComb',
#  'H1_Derived_Neuronal_Progenitor_Cultured_Cells_Strong_transcription',
#  'H1_Derived_Neuronal_Progenitor_Cultured_Cells_Weak_Repressed_PolyComb',
#  'H1_Derived_Neuronal_Progenitor_Cultured_Cells_Weak_transcription',
#  'H1_Derived_Neuronal_Progenitor_Cultured_Cells_ZNF_genes_and_repeats',
#  'H9_Cell_Line_Active_TSS',
#  'H9_Cell_Line_Bivalent_Poised_TSS',
#  'H9_Cell_Line_Enhancers',
#  'H9_Cell_Line_Flanking_Active_TSS',
#  'H9_Cell_Line_Heterochromatin',
#  'H9_Cell_Line_Quiescent_Low',
#  'H9_Cell_Line_Repressed_PolyComb',
#  'H9_Cell_Line_Strong_transcription',
#  'H9_Cell_Line_Weak_Repressed_PolyComb',
#  'H9_Cell_Line_Weak_transcription',
#  'H9_Cell_Line_ZNF_genes_and_repeats',
#  'H9_Derived_Neuronal_Progenitor_Cultured_Cells_Active_TSS',
#  'H9_Derived_Neuronal_Progenitor_Cultured_Cells_Bivalent_Enhancer',
#  'H9_Derived_Neuronal_Progenitor_Cultured_Cells_Bivalent_Poised_TSS',
#  'H9_Derived_Neuronal_Progenitor_Cultured_Cells_Enhancers',
#  'H9_Derived_Neuronal_Progenitor_Cultured_Cells_Flanking_Active_TSS',
#  'H9_Derived_Neuronal_Progenitor_Cultured_Cells_Genic_enhancers',
#  'H9_Derived_Neuronal_Progenitor_Cultured_Cells_Heterochromatin',
#  'H9_Derived_Neuronal_Progenitor_Cultured_Cells_Quiescent_Low',
#  'H9_Derived_Neuronal_Progenitor_Cultured_Cells_Repressed_PolyComb',
#  'H9_Derived_Neuronal_Progenitor_Cultured_Cells_Strong_transcription',
#  'H9_Derived_Neuronal_Progenitor_Cultured_Cells_Weak_Repressed_PolyComb',
#  'H9_Derived_Neuronal_Progenitor_Cultured_Cells_Weak_transcription',
#  'H9_Derived_Neuronal_Progenitor_Cultured_Cells_ZNF_genes_and_repeats',
#  'H9_Derived_Neuron_Cultured_Cells_Active_TSS',
#  'H9_Derived_Neuron_Cultured_Cells_Bivalent_Enhancer',
#  'H9_Derived_Neuron_Cultured_Cells_Bivalent_Poised_TSS',
#  'H9_Derived_Neuron_Cultured_Cells_Enhancers',
#  'H9_Derived_Neuron_Cultured_Cells_Flanking_Active_TSS',
#  'H9_Derived_Neuron_Cultured_Cells_Flanking_Bivalent_TSS_Enh',
#  'H9_Derived_Neuron_Cultured_Cells_Genic_enhancers',
#  'H9_Derived_Neuron_Cultured_Cells_Heterochromatin',
#  'H9_Derived_Neuron_Cultured_Cells_Quiescent_Low',
#  'H9_Derived_Neuron_Cultured_Cells_Repressed_PolyComb',
#  'H9_Derived_Neuron_Cultured_Cells_Strong_transcription',
#  'H9_Derived_Neuron_Cultured_Cells_Weak_Repressed_PolyComb',
#  'H9_Derived_Neuron_Cultured_Cells_Weak_transcription',
#  'H9_Derived_Neuron_Cultured_Cells_ZNF_genes_and_repeats',
#  'HeLa_S3_Cervical_Carcinoma_Active_TSS',
#  'HeLa_S3_Cervical_Carcinoma_Enhancers',
#  'HeLa_S3_Cervical_Carcinoma_Flanking_Active_TSS',
#  'HeLa_S3_Cervical_Carcinoma_Genic_enhancers',
#  'HeLa_S3_Cervical_Carcinoma_Heterochromatin',
#  'HeLa_S3_Cervical_Carcinoma_Quiescent_Low',
#  'HeLa_S3_Cervical_Carcinoma_Repressed_PolyComb',
#  'HeLa_S3_Cervical_Carcinoma_Strong_transcription',
#  'HeLa_S3_Cervical_Carcinoma_Weak_Repressed_PolyComb',
#  'HeLa_S3_Cervical_Carcinoma_Weak_transcription',
#  'HepG2_Hepatocellular_Carcinoma_Active_TSS',
#  'HepG2_Hepatocellular_Carcinoma_Bivalent_Enhancer',
#  'HepG2_Hepatocellular_Carcinoma_Bivalent_Poised_TSS',
#  'HepG2_Hepatocellular_Carcinoma_Enhancers',
#  'HepG2_Hepatocellular_Carcinoma_Flanking_Active_TSS',
#  'HepG2_Hepatocellular_Carcinoma_Flanking_Bivalent_TSS_Enh',
#  'HepG2_Hepatocellular_Carcinoma_Genic_enhancers',
#  'HepG2_Hepatocellular_Carcinoma_Heterochromatin',
#  'HepG2_Hepatocellular_Carcinoma_Quiescent_Low',
#  'HepG2_Hepatocellular_Carcinoma_Repressed_PolyComb',
#  'HepG2_Hepatocellular_Carcinoma_Strong_transcription',
#  'HepG2_Hepatocellular_Carcinoma_Weak_Repressed_PolyComb',
#  'HepG2_Hepatocellular_Carcinoma_Weak_transcription',
#  'HepG2_Hepatocellular_Carcinoma_ZNF_genes_and_repeats',
#  'hESC_Derived_CD184pp_Endoderm_Cultured_Cells_Active_TSS',
#  'hESC_Derived_CD184pp_Endoderm_Cultured_Cells_Bivalent_Enhancer',
#  'hESC_Derived_CD184pp_Endoderm_Cultured_Cells_Bivalent_Poised_TSS',
#  'hESC_Derived_CD184pp_Endoderm_Cultured_Cells_Enhancers',
#  'hESC_Derived_CD184pp_Endoderm_Cultured_Cells_Flanking_Active_TSS',
#  'hESC_Derived_CD184pp_Endoderm_Cultured_Cells_Genic_enhancers',
#  'hESC_Derived_CD184pp_Endoderm_Cultured_Cells_Heterochromatin',
#  'hESC_Derived_CD184pp_Endoderm_Cultured_Cells_Quiescent_Low',
#  'hESC_Derived_CD184pp_Endoderm_Cultured_Cells_Repressed_PolyComb',
#  'hESC_Derived_CD184pp_Endoderm_Cultured_Cells_Strong_transcription',
#  'hESC_Derived_CD184pp_Endoderm_Cultured_Cells_Weak_Repressed_PolyComb',
#  'hESC_Derived_CD184pp_Endoderm_Cultured_Cells_Weak_transcription',
#  'hESC_Derived_CD184pp_Endoderm_Cultured_Cells_ZNF_genes_and_repeats',
#  'hESC_Derived_CD56pp_Ectoderm_Cultured_Cells_Active_TSS',
#  'hESC_Derived_CD56pp_Ectoderm_Cultured_Cells_Bivalent_Enhancer',
#  'hESC_Derived_CD56pp_Ectoderm_Cultured_Cells_Bivalent_Poised_TSS',
#  'hESC_Derived_CD56pp_Ectoderm_Cultured_Cells_Enhancers',
#  'hESC_Derived_CD56pp_Ectoderm_Cultured_Cells_Flanking_Active_TSS',
#  'hESC_Derived_CD56pp_Ectoderm_Cultured_Cells_Flanking_Bivalent_TSS_Enh',
#  'hESC_Derived_CD56pp_Ectoderm_Cultured_Cells_Heterochromatin',
#  'hESC_Derived_CD56pp_Ectoderm_Cultured_Cells_Quiescent_Low',
#  'hESC_Derived_CD56pp_Ectoderm_Cultured_Cells_Repressed_PolyComb',
#  'hESC_Derived_CD56pp_Ectoderm_Cultured_Cells_Strong_transcription',
#  'hESC_Derived_CD56pp_Ectoderm_Cultured_Cells_Weak_Repressed_PolyComb',
#  'hESC_Derived_CD56pp_Ectoderm_Cultured_Cells_Weak_transcription',
#  'hESC_Derived_CD56pp_Mesoderm_Cultured_Cells_Active_TSS',
#  'hESC_Derived_CD56pp_Mesoderm_Cultured_Cells_Bivalent_Poised_TSS',
#  'hESC_Derived_CD56pp_Mesoderm_Cultured_Cells_Enhancers',
#  'hESC_Derived_CD56pp_Mesoderm_Cultured_Cells_Flanking_Active_TSS',
#  'hESC_Derived_CD56pp_Mesoderm_Cultured_Cells_Genic_enhancers',
#  'hESC_Derived_CD56pp_Mesoderm_Cultured_Cells_Heterochromatin',
#  'hESC_Derived_CD56pp_Mesoderm_Cultured_Cells_Quiescent_Low',
#  'hESC_Derived_CD56pp_Mesoderm_Cultured_Cells_Repressed_PolyComb',
#  'hESC_Derived_CD56pp_Mesoderm_Cultured_Cells_Strong_transcription',
#  'hESC_Derived_CD56pp_Mesoderm_Cultured_Cells_Weak_Repressed_PolyComb',
#  'hESC_Derived_CD56pp_Mesoderm_Cultured_Cells_Weak_transcription',
#  'hESC_Derived_CD56pp_Mesoderm_Cultured_Cells_ZNF_genes_and_repeats',
#  'HMEC_Mammary_Epithelial_Active_TSS',
#  'HMEC_Mammary_Epithelial_Enhancers',
#  'HMEC_Mammary_Epithelial_Flanking_Active_TSS',
#  'HMEC_Mammary_Epithelial_Genic_enhancers',
#  'HMEC_Mammary_Epithelial_Heterochromatin',
#  'HMEC_Mammary_Epithelial_Quiescent_Low',
#  'HMEC_Mammary_Epithelial_Repressed_PolyComb',
#  'HMEC_Mammary_Epithelial_Strong_transcription',
#  'HMEC_Mammary_Epithelial_Weak_Repressed_PolyComb',
#  'HMEC_Mammary_Epithelial_Weak_transcription',
#  'HMEC_Mammary_Epithelial_ZNF_genes_and_repeats',
#  'HSMM_Skeletal_Muscle_Myoblasts_Active_TSS',
#  'HSMM_Skeletal_Muscle_Myoblasts_Bivalent_Poised_TSS',
#  'HSMM_Skeletal_Muscle_Myoblasts_Enhancers',
#  'HSMM_Skeletal_Muscle_Myoblasts_Flanking_Active_TSS',
#  'HSMM_Skeletal_Muscle_Myoblasts_Genic_enhancers',
#  'HSMM_Skeletal_Muscle_Myoblasts_Heterochromatin',
#  'HSMM_Skeletal_Muscle_Myoblasts_Quiescent_Low',
#  'HSMM_Skeletal_Muscle_Myoblasts_Repressed_PolyComb',
#  'HSMM_Skeletal_Muscle_Myoblasts_Strong_transcription',
#  'HSMM_Skeletal_Muscle_Myoblasts_Transcr_at_gene_5_and_3',
#  'HSMM_Skeletal_Muscle_Myoblasts_Weak_Repressed_PolyComb',
#  'HSMM_Skeletal_Muscle_Myoblasts_Weak_transcription',
#  'HSMM_Skeletal_Muscle_Myoblasts_ZNF_genes_and_repeats',
#  'HSMMtube_Skeletal_Muscle_Myotubes_Derived_from_HSMM_Active_TSS',
#  'HSMMtube_Skeletal_Muscle_Myotubes_Derived_from_HSMM_Enhancers',
#  'HSMMtube_Skeletal_Muscle_Myotubes_Derived_from_HSMM_Flanking_Active_TSS',
#  'HSMMtube_Skeletal_Muscle_Myotubes_Derived_from_HSMM_Genic_enhancers',
#  'HSMMtube_Skeletal_Muscle_Myotubes_Derived_from_HSMM_Heterochromatin',
#  'HSMMtube_Skeletal_Muscle_Myotubes_Derived_from_HSMM_Quiescent_Low',
#  'HSMMtube_Skeletal_Muscle_Myotubes_Derived_from_HSMM_Repressed_PolyComb',
#  'HSMMtube_Skeletal_Muscle_Myotubes_Derived_from_HSMM_Strong_transcription',
#  'HSMMtube_Skeletal_Muscle_Myotubes_Derived_from_HSMM_Weak_Repressed_PolyComb',
#  'HSMMtube_Skeletal_Muscle_Myotubes_Derived_from_HSMM_Weak_transcription',
#  'HSMMtube_Skeletal_Muscle_Myotubes_Derived_from_HSMM_ZNF_genes_and_repeats',
#  'HUES48_Cell_Line_Active_TSS',
#  'HUES48_Cell_Line_Bivalent_Enhancer',
#  'HUES48_Cell_Line_Bivalent_Poised_TSS',
#  'HUES48_Cell_Line_Enhancers',
#  'HUES48_Cell_Line_Flanking_Active_TSS',
#  'HUES48_Cell_Line_Flanking_Bivalent_TSS_Enh',
#  'HUES48_Cell_Line_Genic_enhancers',
#  'HUES48_Cell_Line_Heterochromatin',
#  'HUES48_Cell_Line_Quiescent_Low',
#  'HUES48_Cell_Line_Repressed_PolyComb',
#  'HUES48_Cell_Line_Strong_transcription',
#  'HUES48_Cell_Line_Weak_Repressed_PolyComb',
#  'HUES48_Cell_Line_Weak_transcription',
#  'HUES48_Cell_Line_ZNF_genes_and_repeats',
#  'HUES64_Cell_Line_Active_TSS',
#  'HUES64_Cell_Line_Bivalent_Enhancer',
#  'HUES64_Cell_Line_Bivalent_Poised_TSS',
#  'HUES64_Cell_Line_Enhancers',
#  'HUES64_Cell_Line_Flanking_Active_TSS',
#  ...]
