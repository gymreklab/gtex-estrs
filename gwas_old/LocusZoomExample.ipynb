# %%
# Which eSTR to plot
CHROM=10
GENE="ENSG00000151640.8"
START=134000824
TISSUE="Cells-Transformedfibroblasts"
WINDOW=100000

# Imports
from wand.image import Image as WImage

# %%
# %%bash -s "$CHROM" "$START" "$TISSUE" "$GENE"
#
# CHROM=$1
# START=$2
# TISSUE=$3
# GENE=$4
#
# # Pull out data in epacts format
# # The chrom, start, end, marker ID, and p-value columns must all be present. The file must be tab-delimited.
# echo "#CHROM,BEGIN,END,MARKER_ID,NS,AC,CALLRATE,MAF,PVALUE,SCORE,N.CASE,N.CTRL,AF.CASE,AF.CTRL" | sed 's/,/\t/g'> pvals.txt
#
# cat /storage/szfeupe/Runs/650GTEx_estr/Analysis_by_Tissue/${TISSUE}/Lin_Reg_Out | \
#     grep -w ${START} | grep -w ${GENE} | sed 's/chr//' | \
#     awk '{print $2 "\t" $4 "\t" $4 "\t" $3 "\t" "NS\tAC\tCALLRATE\tMAF\t" $12 "\t" "SCORE\tNCASE\tNCTRL\tAFCASE\tAFCTRL"}' >> pvals.txt
# cat /storage/szfeupe/Runs/650GTEx_estr/Analysis_by_Tissue/${TISSUE}/SNP_Analysis/Lin_Reg_Out | cut -f 1 --complement | \
#     grep -w ${GENE} | sed 's/chr//' | \
#     awk '{print $2 "\t" $4 "\t" $4 "\t" $3 "\t" "NS\tAC\tCALLRATE\tMAF\t" $12 "\t" "SCORE\tNCASE\tNCTRL\tAFCASE\tAFCTRL"}' |
#     sed 's/STR_/SNP_/' >> pvals.txt

# %%
# %%bash -s "$CHROM" "$START" "$TISSUE" "$GENE"
#
# CHROM=$1
# START=$2
# TISSUE=$3
# GENE=$4
#
# source params.sh
#
# # Compute LD
# cat pvals.txt | grep -v "STR" | grep -v "CHROM" | cut -f 2 | \
#     awk -v"chrom=$CHROM" -v"start=$START" '{print chrom "\t" start "\t" $0}' > snpstr.tab
# echo "snp1,snp2,dprime,rsquare" | sed 's/,/\t/g' > ld.txt
# echo "STR_${START},STR_${START},NA,1" | sed 's/,/\t/g' >> ld.txt
# /home/mgymrek/workspace/ssc-imputation/snpstr-ld/snp_str_ld_calculator.py \
#     --str-vcf ${STRVCF} --snp-vcf ${SNPVCF} --loci-file snpstr.tab \
#     --use-info-start --mincount 3 --usefilter --use-gb | \
#     grep -v locus1 | sed 's/:/\t/g' | \
#     awk -v"chrom=$CHROM" '{print "chr"chrom":"$4 "\t" "chr"chrom":"$2 "\tNA\t" $9}' >> ld.txt
# Out:
# ERROR: couldn't find SNP record for 133914303
# ERROR: couldn't find SNP record for 133914316
# ERROR: couldn't find SNP record for 133914339
# ERROR: couldn't find SNP record for 133914879
# ERROR: couldn't find SNP record for 133916828
# ERROR: couldn't find SNP record for 133916912
# ERROR: couldn't find SNP record for 133916913
# ERROR: couldn't find SNP record for 133916919
# ERROR: couldn't find SNP record for 133916922
# ERROR: couldn't find SNP record for 133916924
# ERROR: couldn't find SNP record for 133916926
# ERROR: couldn't find SNP record for 133916927
# ERROR: couldn't find SNP record for 133916941
# ERROR: couldn't find SNP record for 133916946
# ERROR: couldn't find SNP record for 133916947
# ERROR: couldn't find SNP record for 133916950
# ERROR: couldn't find SNP record for 133916953
# ERROR: couldn't find SNP record for 133916954
# ERROR: couldn't find SNP record for 133916958
# ERROR: couldn't find SNP record for 133916959
# ERROR: couldn't find SNP record for 133916960
# ERROR: couldn't find SNP record for 133916969
# ERROR: couldn't find SNP record for 133921850
# ERROR: couldn't find SNP record for 134035407
# ERROR: couldn't find SNP record for 134050684
# ERROR: couldn't find SNP record for 134050685
# ERROR: couldn't find SNP record for 134066993
# ERROR: couldn't find SNP record for 134067000
# ERROR: couldn't find SNP record for 134067001
# ERROR: couldn't find SNP record for 134067002
# ERROR: couldn't find SNP record for 134067003
# ERROR: couldn't find SNP record for 134067009
# ERROR: couldn't find SNP record for 134067011
# ERROR: couldn't find SNP record for 134067012
# ERROR: couldn't find SNP record for 134067020
# ERROR: couldn't find SNP record for 134067030
# ERROR: couldn't find SNP record for 134067063
# ERROR: couldn't find SNP record for 134068256
# ERROR: couldn't find SNP record for 134068264
# ERROR: couldn't find SNP record for 134072522
# ERROR: couldn't find SNP record for 134072536
# ERROR: couldn't find SNP record for 134072539
# ERROR: couldn't find SNP record for 134072540
# ERROR: couldn't find SNP record for 134072580
# ERROR: couldn't find SNP record for 134078594
# ERROR: couldn't find SNP record for 134078595
# ERROR: couldn't find SNP record for 134078598
# ERROR: couldn't find SNP record for 134078599
# ERROR: couldn't find SNP record for 134078601
# ERROR: couldn't find SNP record for 134078602
# ERROR: couldn't find SNP record for 134078607
# ERROR: couldn't find SNP record for 134078615
# ERROR: couldn't find SNP record for 134078627
# ERROR: couldn't find SNP record for 134078639
# ERROR: couldn't find SNP record for 134078645
# ERROR: couldn't find SNP record for 134078662
# ERROR: couldn't find SNP record for 134078678
# ERROR: couldn't find SNP record for 134078734
# ERROR: couldn't find SNP record for 134080988
# ERROR: couldn't find SNP record for 134081012
# ERROR: couldn't find SNP record for 134081214
# ERROR: couldn't find SNP record for 134081220
# ERROR: couldn't find SNP record for 134081258
# ERROR: couldn't find SNP record for 134081294
# ERROR: couldn't find SNP record for 134081422
# ERROR: couldn't find SNP record for 134081546
# ERROR: couldn't find SNP record for 134081548
# ERROR: couldn't find SNP record for 134081550
# ERROR: couldn't find SNP record for 134081559
# ERROR: couldn't find SNP record for 134081803
# ERROR: couldn't find SNP record for 134082165
# ERROR: couldn't find SNP record for 134087354
# ERROR: couldn't find SNP record for 134093211
# ERROR: couldn't find SNP record for 134093418
# ERROR: couldn't find SNP record for 134093863
# ERROR: couldn't find SNP record for 134094068
# ERROR: couldn't find SNP record for 134094532
# ERROR: couldn't find SNP record for 134095961
# ERROR: couldn't find SNP record for 134095967
# ERROR: couldn't find SNP record for 134095977
# ERROR: couldn't find SNP record for 134095978
# ERROR: couldn't find SNP record for 134095983
# ERROR: couldn't find SNP record for 134095993
# ERROR: couldn't find SNP record for 134096014
# ERROR: couldn't find SNP record for 134097926
# ERROR: couldn't find SNP record for 134097944
# ERROR: couldn't find SNP record for 134098318
# ERROR: couldn't find SNP record for 134098319

# %%
# %%bash -s "$CHROM" "$START" "$WINDOW"
# CHROM=$1
# START=$2
# WINDOW=$3
#
# # Run locus zoom
# /storage/resources/source/locuszoom/bin/locuszoom \
#     --epacts pvals.txt \
#     --chr ${CHROM} --start $((START-$WINDOW)) --end $((START+$WINDOW)) \
#     --ld ld.txt --build hg19 \
#     --prefix lz/test > /dev/null

# %%
# Display PDF
fname = 'lz/test_180323_chr%s_%s-%s/chr%s_%s-%s.pdf'%(CHROM,START-WINDOW,START+WINDOW,CHROM,START-WINDOW,START+WINDOW)
img = WImage(filename=fname)
print(fname)
img
# Out:
# lz/test_180323_chr10_133900824-134100824/chr10_133900824-134100824.pdf
# <wand.image.Image: 49850df 'PDF' (720x504)>
